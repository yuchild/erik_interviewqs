# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/ddi_message_app_data.csv')

# %%
data
# Out:
#            date  sender_id  receiver_id
# 0    2018-03-01          5            2
# 1    2018-03-01          8            6
# 2    2018-03-01          1            2
# 3    2018-03-01          4            8
# 4    2018-03-01          2            7
# ..          ...        ...          ...
# 994  2018-03-03          7            1
# 995  2018-03-03          3            9
# 996  2018-03-03          6            8
# 997  2018-03-03         10            6
# 998  2018-03-03          2            7
#
# [999 rows x 3 columns]

# %%
"""
Using Python, calculate what fraction of senders sent messages to at least 9 unique people on March 1, 2018.

"""
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         999 non-null    object
#  1   sender_id    999 non-null    int64
#  2   receiver_id  999 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 23.5+ KB

# %%
data_date = data[data['date'] == '2018-03-01']

# %%
data_date.shape
# Out:
# (459, 3)

# %%
data_date['date'].nunique(), data_date['sender_id'].nunique(), data_date['receiver_id'].nunique()
# Out:
# (1, 10, 10)

# %%
tuples = []
for i in range(0, data_date.shape[0]):
    tuples.append((data_date['sender_id'].iloc[i], data_date['receiver_id'].iloc[i]))
len(tuples)
# Out:
# 459

# %%
tuples
# Out:
# [(5, 2),
#  (8, 6),
#  (1, 2),
#  (4, 8),
#  (2, 7),
#  (7, 1),
#  (4, 7),
#  (6, 2),
#  (1, 7),
#  (4, 3),
#  (5, 8),
#  (6, 7),
#  (3, 6),
#  (3, 6),
#  (8, 7),
#  (2, 10),
#  (2, 8),
#  (2, 8),
#  (4, 5),
#  (10, 2),
#  (6, 9),
#  (9, 1),
#  (3, 5),
#  (1, 10),
#  (6, 5),
#  (8, 5),
#  (6, 5),
#  (1, 7),
#  (1, 5),
#  (8, 4),
#  (5, 4),
#  (6, 2),
#  (1, 5),
#  (3, 5),
#  (2, 8),
#  (9, 8),
#  (7, 4),
#  (6, 10),
#  (6, 3),
#  (2, 4),
#  (3, 7),
#  (6, 9),
#  (10, 7),
#  (4, 1),
#  (6, 8),
#  (8, 4),
#  (4, 6),
#  (5, 2),
#  (2, 4),
#  (1, 5),
#  (10, 4),
#  (6, 2),
#  (5, 7),
#  (6, 1),
#  (6, 3),
#  (8, 5),
#  (8, 5),
#  (4, 2),
#  (4, 8),
#  (9, 4),
#  (5, 9),
#  (1, 10),
#  (4, 9),
#  (2, 3),
#  (4, 9),
#  (7, 3),
#  (8, 5),
#  (10, 7),
#  (3, 7),
#  (9, 3),
#  (5, 1),
#  (5, 4),
#  (9, 6),
#  (5, 3),
#  (9, 7),
#  (8, 4),
#  (10, 4),
#  (5, 10),
#  (3, 4),
#  (2, 3),
#  (1, 9),
#  (2, 7),
#  (5, 4),
#  (4, 9),
#  (3, 10),
#  (2, 7),
#  (4, 5),
#  (6, 3),
#  (6, 9),
# ...

# %%
tuples_dict = {}
for t in tuples:
    if t in tuples_dict:
        tuples_dict[t] += 1
    else:
        tuples_dict[t] = 1
tuples_dict
# Out:
# {(5, 2): 5,
#  (8, 6): 5,
#  (1, 2): 8,
#  (4, 8): 9,
#  (2, 7): 12,
#  (7, 1): 2,
#  (4, 7): 6,
#  (6, 2): 8,
#  (1, 7): 8,
#  (4, 3): 7,
#  (5, 8): 9,
#  (6, 7): 8,
#  (3, 6): 9,
#  (8, 7): 6,
#  (2, 10): 6,
#  (2, 8): 6,
#  (4, 5): 9,
#  (10, 2): 4,
#  (6, 9): 10,
#  (9, 1): 8,
#  (3, 5): 6,
#  (1, 10): 11,
#  (6, 5): 2,
#  (8, 5): 11,
#  (1, 5): 6,
#  (8, 4): 4,
#  (5, 4): 7,
#  (9, 8): 3,
#  (7, 4): 4,
#  (6, 10): 3,
#  (6, 3): 5,
#  (2, 4): 7,
#  (3, 7): 5,
#  (10, 7): 5,
#  (4, 1): 7,
#  (6, 8): 4,
#  (4, 6): 5,
#  (10, 4): 5,
#  (5, 7): 3,
#  (6, 1): 7,
#  (4, 2): 9,
#  (9, 4): 5,
#  (5, 9): 6,
#  (4, 9): 6,
#  (2, 3): 5,
#  (7, 3): 5,
#  (9, 3): 2,
#  (5, 1): 8,
#  (9, 6): 5,
#  (5, 3): 2,
#  (9, 7): 5,
#  (5, 10): 4,
#  (3, 4): 5,
#  (1, 9): 4,
#  (3, 10): 3,
#  (10, 9): 3,
#  (2, 1): 2,
#  (1, 8): 4,
#  (1, 4): 11,
#  (10, 1): 8,
#  (8, 10): 3,
#  (10, 5): 4,
#  (7, 2): 3,
#  (8, 9): 4,
#  (2, 5): 5,
#  (3, 8): 5,
#  (2, 9): 5,
#  (9, 2): 3,
#  (7, 10): 5,
#  (8, 3): 6,
# ...

# %%
sender_dict = {}
for x in tuples_dict:
    if x[0] in sender_dict:
        sender_dict[x[0]] += 1
    else:
        sender_dict[x[0]] = 1
sender_dict
# Out:
# {5: 9, 8: 9, 1: 9, 4: 9, 2: 9, 7: 8, 6: 9, 3: 9, 10: 9, 9: 9}

# %%
len(tuples_dict)
# Out:
# 89

# %%
popular_senders = []
for key in sender_dict:
    if sender_dict[key] >= 9:
        popular_senders.append(key)

# %%
popular_senders
# Out:
# [5, 8, 1, 4, 2, 6, 3, 10, 9]

# %%
unique_senders = data['sender_id'].nunique()
unique_senders
# Out:
# 10

# %%
percent_popular = len(popular_senders) / unique_senders
percent_popular
# Out:
# 0.9

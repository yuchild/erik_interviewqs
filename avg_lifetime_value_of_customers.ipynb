# %%
"""
Given the following dataset, calculate the average lifetime value of a customer.

    
Below are a couple of definitions to help solve the problem:
    
Lifetime value is average revenue divided by the churn rate

Churn rate is defined as the total number of churned customers / total number of customers
     
Additionally, here is code to import the relevant packages as well as the dataset shown above, 
to help get you started:
    
#Importing packages

import pandas as pd

import numpy as np
    

#Read in the dataset
    
data = pd.read_csv("https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/teleco_user_data.csv") 
    
#Convert these column types to int
    
data['TotalCharges'] = pd.to_numeric(data.TotalCharges, downcast='integer', errors='coerce')

data['MonthlyCharges'] = pd.to_numeric(data.MonthlyCharges, downcast='integer', errors='coerce')
"""

import pandas as pd
import numpy as np

# load data, done on 2021-10-18
# url = "https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/teleco_user_data.csv"
# df = pd.read_csv(url)
# df['TotalCharges'] = pd.to_numeric(df.TotalCharges, downcast='integer', errors='coerce')
# df['MonthlyCharges'] = pd.to_numeric(df.MonthlyCharges, downcast='integer', errors='coerce')
# df.to_pickle('./data/teleco_user_data.pkl')

# %%
# load data
df = pd.read_pickle('./data/teleco_user_data.pkl')
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2356  3450-WXOAT    Male              0      No         No      46
# 5236  7025-IWFHT    Male              0      No         No      41
# 5658  2371-JQHZZ    Male              0     Yes         No      24
# 3535  3612-YUNGG    Male              0     Yes        Yes      64
# 263   7605-BDWDC  Female              0      No         No      31
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 2356          Yes                No             DSL             No  ...
# 5236          Yes                No     Fiber optic             No  ...
# 5658          Yes               Yes     Fiber optic             No  ...
# 3535          Yes               Yes     Fiber optic             No  ...
# 263            No  No phone service             DSL            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 2356               No          No          No              No  Month-to-month
# 5236               No         Yes         Yes              No        One year
# 5658               No          No         Yes             Yes  Month-to-month
# 3535              Yes         Yes         Yes             Yes        Two year
# 263                No         Yes          No             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 2356              Yes    Credit card (automatic)          45.20       2065.15
# 5236              Yes           Electronic check          89.55       3729.75
# 5658              Yes           Electronic check          93.00       2248.05
# 3535              Yes    Credit card (automatic)         109.20       6741.15
# 263               Yes  Bank transfer (automatic)          49.85       1520.10
#
#       Churn
# 2356     No
# 5236     No
# 5658     No
# 3535     No
# 263      No
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns 
#         = ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['TotalCharges'].mean()/(df['Churn'].value_counts().Yes/df['Churn'].value_counts().sum())
# Out:
# 8604.218836195429

# %%
df.sample(15)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3958  4652-NNHNY    Male              0     Yes         No      16
# 4384  8642-GVWRF  Female              0     Yes         No       2
# 4981  8008-HAWED    Male              0      No         No      14
# 5758  5847-MXBEO    Male              0      No         No      22
# 3673  1723-HKXJQ    Male              0      No         No      42
# 2914  0484-FFVBJ    Male              0      No         No      32
# 11    7469-LKBCI    Male              0      No         No      16
# 1389  8621-MNIHH  Female              1     Yes         No      34
# 4803  3717-LNXKW    Male              0     Yes         No      38
# 6850  0531-XBKMM    Male              0      No        Yes      66
# 3568  2227-JRSJX  Female              0      No         No      21
# 5394  5118-MUEYH  Female              0     Yes         No      48
# 568   0939-YAPAF  Female              0      No         No      35
# 5980  7049-GKVZY  Female              0      No         No      17
# 4914  0562-FGDCR  Female              0     Yes        Yes      72
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 3958          Yes               Yes     Fiber optic                   No  ...
# 4384          Yes                No     Fiber optic                   No  ...
# 4981           No  No phone service             DSL                   No  ...
# 5758          Yes                No              No  No internet service  ...
# 3673          Yes               Yes     Fiber optic                   No  ...
# 2914          Yes                No             DSL                   No  ...
# 11            Yes                No              No  No internet service  ...
# 1389          Yes               Yes     Fiber optic                   No  ...
# 4803          Yes               Yes     Fiber optic                  Yes  ...
# 6850          Yes               Yes             DSL                  Yes  ...
# 3568          Yes                No     Fiber optic                   No  ...
# 5394          Yes               Yes     Fiber optic                   No  ...
# 568           Yes               Yes     Fiber optic                   No  ...
# 5980          Yes                No             DSL                  Yes  ...
# 4914          Yes               Yes             DSL                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 3958                   No                   No                   No
# 4384                  Yes                   No                   No
# 4981                  Yes                   No                  Yes
# 5758  No internet service  No internet service  No internet service
# 3673                   No                   No                  Yes
# 2914                   No                   No                  Yes
# 11    No internet service  No internet service  No internet service
# 1389                  Yes                   No                   No
# 4803                   No                   No                  Yes
# 6850                   No                  Yes                   No
# 3568                   No                  Yes                  Yes
# 5394                   No                  Yes                  Yes
# 568                   Yes                   No                  Yes
# 5980                   No                  Yes                  Yes
# 4914                   No                  Yes                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 3958                   No  Month-to-month              Yes
# 4384                   No  Month-to-month               No
# 4981                  Yes  Month-to-month              Yes
# 5758  No internet service        One year               No
# 3673                  Yes  Month-to-month              Yes
# 2914                  Yes        One year              Yes
# 11    No internet service        Two year               No
# 1389                  Yes  Month-to-month              Yes
# 4803                   No  Month-to-month               No
# 6850                   No        Two year               No
# 3568                  Yes  Month-to-month              Yes
# 5394                  Yes  Month-to-month              Yes
# 568                   Yes  Month-to-month              Yes
# 5980                  Yes        One year               No
# 4914                   No        Two year               No
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 3958  Bank transfer (automatic)          73.85       1284.20    Yes
# 4384  Bank transfer (automatic)          79.70        165.00    Yes
# 4981           Electronic check          50.75        712.75    Yes
# 5758               Mailed check          20.30        475.10     No
# 3673           Electronic check         101.75       4273.45    Yes
# 2914  Bank transfer (automatic)          64.85       2010.95     No
# 11      Credit card (automatic)          18.95        326.80     No
# 1389           Electronic check          94.25       3217.55    Yes
# 4803  Bank transfer (automatic)          91.70       3479.05     No
# 6850  Bank transfer (automatic)          65.70       4378.90     No
# 3568  Bank transfer (automatic)          99.15       1956.40     No
# 5394    Credit card (automatic)         105.10       5083.55     No
# 568            Electronic check         100.25       3527.60    Yes
# 5980    Credit card (automatic)          79.85       1387.35     No
# 4914               Mailed check          74.55       5430.65     No
#
# [15 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
df[['tenure', 'MonthlyCharges', 'TotalCharges']].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7032.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2266.771362
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.850000   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
df['tenure'].loc[df['Churn']=='Yes'].hist(bins = 5);

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df.groupby(['Churn', 'gender'])['gender'].count() #sometimes sum() is count()!!!
# Out:
# Churn  gender
# No     Female    2549
#        Male      2625
# Yes    Female     939
#        Male       930
# Name: gender, dtype: int64

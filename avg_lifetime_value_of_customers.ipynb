# %%
"""
Given the following dataset, calculate the average lifetime value of a customer.

    
Below are a couple of definitions to help solve the problem:
    
Lifetime value is average revenue divided by the churn rate

Churn rate is defined as the total number of churned customers / total number of customers
     
Additionally, here is code to import the relevant packages as well as the dataset shown above, 
to help get you started:
    
#Importing packages

import pandas as pd

import numpy as np
    

#Read in the dataset
    
data = pd.read_csv("https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/teleco_user_data.csv") 
    
#Convert these column types to int
    
data['TotalCharges'] = pd.to_numeric(data.TotalCharges, downcast='integer', errors='coerce')

data['MonthlyCharges'] = pd.to_numeric(data.MonthlyCharges, downcast='integer', errors='coerce')
"""

import pandas as pd
import numpy as np

# load data, done on 2021-10-18
# url = "https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/teleco_user_data.csv"
# df = pd.read_csv(url)
# df['TotalCharges'] = pd.to_numeric(df.TotalCharges, downcast='integer', errors='coerce')
# df['MonthlyCharges'] = pd.to_numeric(df.MonthlyCharges, downcast='integer', errors='coerce')
# df.to_pickle('./data/teleco_user_data.pkl')

# %%
# load data
df = pd.read_pickle('./data/teleco_user_data.pkl')
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5191  5982-PSMKW  Female              0     Yes        Yes      23
# 5198  0643-OKLRP  Female              1     Yes         No      47
# 2898  6505-OZNPG  Female              0      No         No       6
# 3378  5766-FTRTS    Male              0     Yes         No      72
# 2438  7089-IVVAZ  Female              0      No         No       8
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 5191          Yes               Yes             DSL            Yes  ...
# 5198          Yes               Yes     Fiber optic            Yes  ...
# 2898           No  No phone service             DSL            Yes  ...
# 3378          Yes                No             DSL            Yes  ...
# 2438          Yes               Yes     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 5191              Yes         Yes         Yes             Yes        Two year
# 5198               No          No          No              No  Month-to-month
# 2898              Yes         Yes         Yes             Yes        Two year
# 3378              Yes         Yes         Yes             Yes        Two year
# 2438               No         Yes         Yes             Yes  Month-to-month
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 5191              Yes    Credit card (automatic)          91.10       2198.30
# 5198               No           Electronic check          80.35       3825.85
# 2898              Yes               Mailed check          63.40        348.80
# 3378               No               Mailed check          84.45       6033.10
# 2438              Yes  Bank transfer (automatic)         103.35        847.30
#
#       Churn
# 5191     No
# 5198    Yes
# 2898     No
# 3378     No
# 2438    Yes
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns 
#         = ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['TotalCharges'].mean()/(df['Churn'].value_counts().Yes/df['Churn'].value_counts().sum())
# Out:
# 8604.218836195429

# %%
df.sample(15)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1741  0106-GHRQR    Male              0      No         No      16
# 1834  8080-DDEMJ    Male              1      No         No       1
# 1306  0201-OAMXR  Female              0      No         No      70
# 4744  6139-ZZRBQ    Male              1      No         No      64
# 4231  7998-WNZEM    Male              0      No         No      71
# 2966  8648-PFRMP  Female              1      No         No      14
# 2324  2774-LVQUS  Female              1     Yes         No      15
# 4956  3217-FZDMN  Female              1      No         No       8
# 501   4513-CXYIX  Female              1     Yes         No      71
# 6314  8873-GLDMH  Female              0      No         No       6
# 5737  7989-VCQOH    Male              0     Yes        Yes      18
# 2721  8225-BTJAU    Male              1      No         No      10
# 3893  5816-SCGFC  Female              1      No         No       7
# 3225  4931-TRZWN  Female              0      No         No      13
# 5245  5902-WBLSE  Female              0     Yes        Yes      70
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1741          Yes               Yes             DSL                   No  ...
# 1834          Yes                No             DSL                   No  ...
# 1306          Yes               Yes     Fiber optic                  Yes  ...
# 4744          Yes                No              No  No internet service  ...
# 4231          Yes               Yes             DSL                  Yes  ...
# 2966           No  No phone service             DSL                   No  ...
# 2324          Yes               Yes     Fiber optic                   No  ...
# 4956          Yes                No     Fiber optic                   No  ...
# 501           Yes               Yes     Fiber optic                  Yes  ...
# 6314          Yes               Yes     Fiber optic                   No  ...
# 5737          Yes                No             DSL                  Yes  ...
# 2721          Yes                No     Fiber optic                   No  ...
# 3893          Yes                No             DSL                   No  ...
# 3225          Yes                No             DSL                  Yes  ...
# 5245          Yes                No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 1741                  Yes                   No                   No
# 1834                   No                   No                   No
# 1306                  Yes                  Yes                  Yes
# 4744  No internet service  No internet service  No internet service
# 4231                  Yes                  Yes                   No
# 2966                   No                   No                  Yes
# 2324                  Yes                  Yes                   No
# 4956                  Yes                   No                  Yes
# 501                    No                   No                   No
# 6314                   No                   No                   No
# 5737                  Yes                  Yes                  Yes
# 2721                   No                   No                   No
# 3893                   No                   No                   No
# 3225                   No                   No                  Yes
# 5245  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 1741                  Yes  Month-to-month              Yes
# 1834                   No  Month-to-month               No
# 1306                  Yes        One year               No
# 4744  No internet service        Two year              Yes
# 4231                  Yes        Two year               No
# 2966                  Yes  Month-to-month              Yes
# 2324                   No  Month-to-month              Yes
# 4956                  Yes  Month-to-month              Yes
# 501                    No        Two year              Yes
# 6314                   No  Month-to-month              Yes
# 5737                  Yes  Month-to-month               No
# 2721                  Yes  Month-to-month              Yes
# 3893                   No  Month-to-month              Yes
# 3225                  Yes  Month-to-month              Yes
# 5245  No internet service        Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 1741  Bank transfer (automatic)          71.40       1212.10     No
# 1834           Electronic check          45.10         45.10    Yes
# 1306    Credit card (automatic)         115.55       8127.60    Yes
# 4744  Bank transfer (automatic)          20.05       1198.05     No
# 4231  Bank transfer (automatic)          80.60       5708.20     No
# 2966           Electronic check          46.35        672.70     No
# 2324           Electronic check          83.05       1258.30    Yes
# 4956    Credit card (automatic)          94.45        742.95    Yes
# 501     Credit card (automatic)          80.70       5676.00     No
# 6314               Mailed check          73.85        401.30     No
# 5737           Electronic check          83.25       1611.15     No
# 2721           Electronic check          79.25        793.55    Yes
# 3893               Mailed check          51.30        419.35     No
# 3225           Electronic check          71.95        923.85     No
# 5245    Credit card (automatic)          20.15       1411.20     No
#
# [15 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
df[['tenure', 'MonthlyCharges', 'TotalCharges']].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7032.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2266.771362
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.850000   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
df['tenure'].loc[df['Churn']=='Yes'].hist(bins = 5);

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df.groupby(['Churn', 'gender'])['gender'].count() #sometimes sum() is count()!!!
# Out:
# Churn  gender
# No     Female    2549
#        Male      2625
# Yes    Female     939
#        Male       930
# Name: gender, dtype: int64

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1025  7868-TMWMZ  Female              1     Yes         No      60
# 983   8603-IJWDN    Male              0      No         No       1
# 2287  5440-FLBQG    Male              1     Yes         No      69
# 5413  6833-JMZYP  Female              0      No         No      15
# 1161  5868-CZJDR    Male              0      No        Yes       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1025          Yes                No     Fiber optic            Yes  ...
# 983           Yes               Yes     Fiber optic             No  ...
# 2287          Yes               Yes     Fiber optic             No  ...
# 5413          Yes                No     Fiber optic             No  ...
# 1161           No  No phone service             DSL             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 1025              Yes         Yes         Yes             Yes        Two year
# 983                No          No          No             Yes  Month-to-month
# 2287              Yes         Yes         Yes             Yes        Two year
# 5413              Yes          No         Yes             Yes  Month-to-month
# 1161               No          No          No              No  Month-to-month
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 1025              Yes  Bank transfer (automatic)         110.00       6668.35
# 983               Yes           Electronic check          86.60         86.60
# 2287              Yes  Bank transfer (automatic)         108.40       7318.20
# 5413              Yes    Credit card (automatic)          94.00       1505.45
# 1161              Yes               Mailed check          31.35         31.35
#
#       Churn
# 1025     No
# 983     Yes
# 2287    Yes
# 5413     No
# 1161    Yes
#
# [5 rows x 21 columns]

# %%
def gender_enc(string):
    if string == 'Female':
        return 0
    else:
        return 1

gender_enc('Male')
# Out:
# 1

# %%
df['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
df['gender'] = df['gender'].apply(lambda row: gender_enc(row)) #axis = 1 means down column(s), axis = 0 means across row(s)
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6739  6994-KERXL       1              0      No         No       4
# 4260  5269-NRGDP       1              0     Yes        Yes      42
# 4196  6963-KQYQB       0              0     Yes        Yes      70
# 4530  1945-XISKS       0              0     Yes         No      67
# 6363  8778-LMWTJ       0              0      No         No       9
# 5929  5828-DWPIL       1              1     Yes         No      62
# 3214  0549-CYCQN       1              1      No         No      51
# 2577  4910-GMJOT       0              0      No         No       1
# 4751  8785-EPNCG       1              0      No         No      11
# 3927  4390-KYULV       1              0     Yes         No       3
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 6739          Yes            No             DSL                   No  ...
# 4260          Yes            No             DSL                   No  ...
# 4196          Yes           Yes              No  No internet service  ...
# 4530          Yes            No              No  No internet service  ...
# 6363          Yes            No     Fiber optic                  Yes  ...
# 5929          Yes           Yes     Fiber optic                  Yes  ...
# 3214          Yes           Yes     Fiber optic                   No  ...
# 2577          Yes           Yes     Fiber optic                   No  ...
# 4751          Yes           Yes              No  No internet service  ...
# 3927          Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 6739                   No                   No                   No
# 4260                  Yes                  Yes                  Yes
# 4196  No internet service  No internet service  No internet service
# 4530  No internet service  No internet service  No internet service
# 6363                   No                   No                   No
# 5929                  Yes                   No                   No
# 3214                   No                   No                   No
# 2577                   No                   No                  Yes
# 4751  No internet service  No internet service  No internet service
# 3927  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 6739                  Yes  Month-to-month              Yes
# 4260                  Yes        One year               No
# 4196  No internet service        Two year               No
# 4530  No internet service        Two year               No
# 6363                   No  Month-to-month              Yes
# 5929                   No  Month-to-month              Yes
# 3214                   No        One year              Yes
# 2577                  Yes  Month-to-month              Yes
# 4751  No internet service  Month-to-month               No
# 3927  No internet service  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 6739           Electronic check          55.90        238.50     No
# 4260           Electronic check          73.15       3088.25     No
# 4196               Mailed check          24.05       1764.75     No
# 4530               Mailed check          19.65       1335.20     No
# 6363           Electronic check          74.85        708.20     No
# 5929           Electronic check          89.10       5618.30     No
# 3214  Bank transfer (automatic)          79.60       3974.70     No
# 2577           Electronic check          94.60         94.60    Yes
# 4751    Credit card (automatic)          23.15        245.20    Yes
# 3927    Credit card (automatic)          20.55         51.15    Yes
#
# [10 rows x 21 columns]

# %%
df['gender'].value_counts()
# Out:
# 1    3555
# 0    3488
# Name: gender, dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.describe().columns
# Out:
# Index(['gender', 'SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
cat_cols = ['Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod']
cat_cols
# Out:
# ['Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
df['Partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
for col in cat_cols:
    print(df[col].value_counts())
    print()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
#
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64
#
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64
#
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64
#
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64
#
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64
#
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64
#
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64
#
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64
#
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: StreamingTV, dtype: int64
#
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64
#
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64
#
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64
#
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
def yes_no(string):
    if string == 'Yes':
        return 1
    else:
        return 0

# %%
def service(string):
    if string == 'Yes':
        return 1
    elif string == 'No':
        return 0 
    else:
        return -1 # no internet/phone service

# %%
def internet_service(string):
    if string == 'Fiber optic':
        return 2
    elif string == 'DSL':
        return 1
    else:
        return 0

# %%
def contract(string):
    if string == 'Month-to-month':
        return 1
    elif string == 'One year':
        return 2
    else:
        return 3

# %%
def pay_meth(string):
    if string == 'Electronic check':
        return 1
    elif string == 'Mailed check':
        return 2
    elif string == 'Bank transfer (automatic)':
        return 3
    else:
        return 4

# %%
import numpy as np

# %%
f = lambda x: x + 5
f(2)
# Out:
# 7

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
# change columns with yes or no categories
yes_no_ = ['Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']
for col in yes_no_:
    df[col] = df[col].apply(lambda row: yes_no(row))

# change columns with internet service categories
internet_service_ = ['InternetService']
for col in internet_service_:
    df[col] =  df[col].apply(lambda row: internet_service(row))

# change columns with yes, no, or no internet or phone categories
service_ = ['MultipleLines'
            , 'OnlineSecurity'
            , 'OnlineBackup'
            , 'DeviceProtection'
            , 'TechSupport'
            , 'StreamingTV'
            , 'StreamingMovies']
for col in service_:
    df[col] = df[col].apply(lambda row: service(row))

# change columns with contract categories
contract_ = ['Contract']
for col in contract_:
    df[col] = df[col].apply(lambda row: contract(row))

# change columns with payment categories
pay_meth_ = ['PaymentMethod']
for col in pay_meth_:
    df[col] = df[col].apply(lambda row: pay_meth(row))
    
df.sample(15)
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 2136  1379-FRVEB       1              0        0           1      15
# 4143  4822-YCXMX       1              0        0           0      25
# 5521  3863-QSTYI       1              0        0           0      59
# 3408  2108-YKQTY       0              0        0           0       4
# 7005  9347-AERRL       1              0        1           0      23
# 1552  2245-ADZFJ       0              0        1           1      31
# 1635  2988-PLAHS       0              0        0           0       3
# 1160  6242-MBHPK       0              1        1           0      23
# 1610  3399-BMLVW       1              0        1           1      51
# 5369  9860-LISIZ       0              0        0           0      34
# 776   9505-SQFSW       0              0        1           1       3
# 1068  5536-RTPWK       1              0        1           0      49
# 3409  4806-DXQCE       0              1        1           0      70
# 2467  6559-RAKOZ       1              0        1           1      49
# 6402  8510-TMWYB       0              0        1           1      54
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 2136             1              1                2               0  ...
# 4143             1              1                2               0  ...
# 5521             1              0                1               0  ...
# 3408             1              0                1               0  ...
# 7005             1              0                0              -1  ...
# 1552             1              1                1               0  ...
# 1635             1              0                1               0  ...
# 1160             1              0                2               1  ...
# 1610             1              0                1               1  ...
# 5369             1              0                0              -1  ...
# 776              0             -1                1               0  ...
# 1068             1              1                2               0  ...
# 3409             1              1                2               1  ...
# 2467             1              1                2               0  ...
# 6402             1              1                1               0  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 2136                 0            0            1                0         1
# 4143                 0            0            0                1         1
# 5521                 1            1            1                0         1
# 3408                 0            0            0                0         1
# 7005                -1           -1           -1               -1         2
# 1552                 0            1            1                1         3
# 1635                 1            0            1                1         2
# 1160                 0            0            1                1         1
# 1610                 0            1            0                0         3
# 5369                -1           -1           -1               -1         1
# 776                  0            0            0                1         1
# 1068                 0            0            1                1         1
# 3409                 1            1            1                1         3
# 2467                 0            1            1                1         2
# 6402                 1            0            0                0         3
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 2136                 1              1           91.00       1430.05     No
# 4143                 1              1           84.80       2043.45    Yes
# 5521                 1              1           64.65       3735.45     No
# 3408                 0              4           50.70        151.30    Yes
# 7005                 0              4           19.30        486.20     No
# 1552                 0              3           80.55       2471.60     No
# 1635                 1              1           69.95        220.45     No
# 1160                 1              1           95.10       2326.05     No
# 1610                 0              4           60.50       3121.45     No
# 5369                 0              2           20.35        673.20     No
# 776                  0              2           40.30         92.50     No
# 1068                 1              3           99.05       4853.75    Yes
# 3409                 1              1          113.65       7714.65     No
# 2467                 1              1           97.95       4917.90     No
# 6402                 1              3           59.80       3246.45     No
#
# [15 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
#  16  PaperlessBilling  7043 non-null   int64
#  17  PaymentMethod     7043 non-null   int64
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(17), object(2)
# memory usage: 1.1+ MB

# %%
df['TotalCharges'].loc[df['TotalCharges'].isnull()] # np.null is from numpy
# Out:
# 488    NaN
# 753    NaN
# 936    NaN
# 1082   NaN
# 1340   NaN
# 3331   NaN
# 3826   NaN
# 4380   NaN
# 5218   NaN
# 6670   NaN
# 6754   NaN
# Name: TotalCharges, dtype: float64

# %%
# df.dropna(axis=0, inplace=True) # delete the rows 
df.fillna(df['TotalCharges'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
#  16  PaperlessBilling  7043 non-null   int64
#  17  PaymentMethod     7043 non-null   int64
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(17), object(2)
# memory usage: 1.1+ MB

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['Churn'] = df['Churn'].apply(lambda row: yes_no(row))
df['Churn'].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
#  16  PaperlessBilling  7043 non-null   int64
#  17  PaymentMethod     7043 non-null   int64
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   float64
#  20  Churn             7043 non-null   int64
# dtypes: float64(2), int64(18), object(1)
# memory usage: 1.1+ MB

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# %%
rfc = RandomForestClassifier(random_state=42
                             , n_jobs=-1
                            )
rfr = RandomForestRegressor(random_state=42
                            , n_jobs=-1
                           )

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 6422  8668-KNZTI       1              0        0           0      52
# 474   9399-APLBT       0              0        1           1       1
# 4679  8218-FFJDS       0              0        1           0      72
# 6120  6218-KNUBD       1              0        0           0       6
# 2462  2585-KTFRE       1              0        0           1       1
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 6422             1              0                1               1  ...
# 474              1              0                2               0  ...
# 4679             1              1                1               1  ...
# 6120             1              0                1               0  ...
# 2462             1              0                1               1  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 6422                 1            0            0                0         2
# 474                  0            0            0                0         1
# 4679                 0            1            1                1         3
# 6120                 0            0            1                0         1
# 2462                 0            1            0                1         1
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 6422                 0              1           53.75       2790.65      0
# 474                  1              1           74.70         74.70      1
# 4679                 1              3           86.40       6058.95      0
# 6120                 0              1           59.45        357.60      0
# 2462                 1              3           70.45         70.45      0
#
# [5 rows x 21 columns]

# %%
int(df.shape[0] * 0.85)
# Out:
# 5986

# %%
split = int(df.shape[0] * 0.85)

df.drop(columns=['customerID'], inplace=True)
df.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 1924       0              1        1           1      22             1
# 1626       1              0        0           0      20             1
# 3111       1              0        1           1      72             1
# 947        0              1        1           1      32             1
# 6593       1              0        1           0      55             0
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 1924              1                2               0             0
# 1626              1                1               1             0
# 3111              1                2               0             1
# 947               1                2               0             0
# 6593             -1                1               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 1924                 0            0            1                0         1
# 1626                 0            1            0                0         1
# 3111                 1            0            1                1         3
# 947                  1            0            1                0         1
# 6593                 1            1            1                1         1
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 1924                 0              3           85.35       1961.60      0
# 1626                 0              3           59.20       1191.20      0
# 3111                 1              1          103.40       7372.65      1
# 947                  1              2           91.35       2896.55      0
# 6593                 1              3           54.55       2978.30      1

# %%
df_train = df[:split].copy()
df_test = df[split:].copy()

# %%
X_train = df_train.drop(columns=['Churn']).copy()
y_train = df_train['Churn'].copy()

X_test = df_test.drop(columns=['Churn']).copy()
y_test = df_test['Churn'].copy()

# %%
rfc.fit(X_train, y_train) # fit the training set with the RandomForestClassifier object rfc
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
df.iloc[-1]
# Out:
# gender                 1.00
# SeniorCitizen          0.00
# Partner                0.00
# Dependents             0.00
# tenure                66.00
# PhoneService           1.00
# MultipleLines          0.00
# InternetService        2.00
# OnlineSecurity         1.00
# OnlineBackup           0.00
# DeviceProtection       1.00
# TechSupport            1.00
# StreamingTV            1.00
# StreamingMovies        1.00
# Contract               3.00
# PaperlessBilling       1.00
# PaymentMethod          3.00
# MonthlyCharges       105.65
# TotalCharges        6844.50
# Churn                  0.00
# Name: 7042, dtype: float64

# %%
df.tail(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 7040             -1                1               1             0
# 7041              1                2               0             0
# 7042              0                2               1             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 7040                 0            0            0                0         1
# 7041                 0            0            0                0         1
# 7042                 1            1            1                1         3
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 7040                 1              1           29.60        346.45      0
# 7041                 1              2           74.40        306.60      1
# 7042                 1              3          105.65       6844.50      0

# %%
X_test.iloc[-1].values
# Out:
# array([1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 6.6000e+01,
#        1.0000e+00, 0.0000e+00, 2.0000e+00, 1.0000e+00, 0.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 3.0000e+00,
#        1.0000e+00, 3.0000e+00, 1.0565e+02, 6.8445e+03])

# %%
X_test.iloc[-1].values.reshape(1,-1)
# Out:
# array([[1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 6.6000e+01,
#         1.0000e+00, 0.0000e+00, 2.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 3.0000e+00,
#         1.0000e+00, 3.0000e+00, 1.0565e+02, 6.8445e+03]])

# %%
rfc.predict(X_test.iloc[-1].values.reshape(1,-1))
# Out:
# array([0])

# %%
rfc.predict(X_test.iloc[-2].values.reshape(1,-1))
# Out:
# array([1])

# %%
rfc.predict(X_test.iloc[-3].values.reshape(1,-1))
# Out:
# array([0])

# %%
rfc.predict(X_test)
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
y_test
# Out:
# 5986    0
# 5987    0
# 5988    0
# 5989    1
# 5990    0
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 1057, dtype: int64

# %%
correct=0
incorrect=0

for i in range(len(y_test)):
    if rfc.predict(X_test.iloc[i].values.reshape(1,-1)) == y_test.iloc[i]:
        correct += 1
    else:
        incorrect += 1

# %%
correct
# Out:
# 841

# %%
incorrect
# Out:
# 216

# %%
correct / (correct + incorrect)
# Out:
# 0.7956480605487228

# %%
# rfc.feature_importances_

# %%
"""
Given the following dataset, calculate the average lifetime value of a customer.

    
Below are a couple of definitions to help solve the problem:
    
Lifetime value is average revenue divided by the churn rate

Churn rate is defined as the total number of churned customers / total number of customers
     
Additionally, here is code to import the relevant packages as well as the dataset shown above, 
to help get you started:
    
#Importing packages

import pandas as pd

import numpy as np
    

#Read in the dataset
    
data = pd.read_csv("https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/teleco_user_data.csv") 
    
#Convert these column types to int
    
data['TotalCharges'] = pd.to_numeric(data.TotalCharges, downcast='integer', errors='coerce')

data['MonthlyCharges'] = pd.to_numeric(data.MonthlyCharges, downcast='integer', errors='coerce')
"""

import pandas as pd
import numpy as np

# load data, done on 2021-10-18
# url = "https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/teleco_user_data.csv"
# df = pd.read_csv(url)
# df['TotalCharges'] = pd.to_numeric(df.TotalCharges, downcast='integer', errors='coerce')
# df['MonthlyCharges'] = pd.to_numeric(df.MonthlyCharges, downcast='integer', errors='coerce')
# df.to_pickle('./data/teleco_user_data.pkl')

# %%
# load data
df = pd.read_pickle('./data/teleco_user_data.pkl')
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5180  0361-HJRDX  Female              0      No         No      68
# 829   5337-IIWKZ    Male              0     Yes        Yes      34
# 2325  3097-PYWXL  Female              0     Yes        Yes       4
# 3906  6372-RFVNS  Female              0     Yes         No       1
# 356   3351-NGXYI  Female              1      No         No      16
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 5180           No  No phone service             DSL                  Yes  ...
# 829            No  No phone service             DSL                   No  ...
# 2325          Yes                No              No  No internet service  ...
# 3906          Yes                No     Fiber optic                   No  ...
# 356           Yes               Yes             DSL                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 5180                  Yes                  Yes                  Yes
# 829                   Yes                  Yes                  Yes
# 2325  No internet service  No internet service  No internet service
# 3906                   No                   No                  Yes
# 356                    No                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 5180                  Yes        Two year               No
# 829                    No  Month-to-month              Yes
# 2325  No internet service  Month-to-month              Yes
# 3906                   No  Month-to-month               No
# 356                    No  Month-to-month              Yes
#
#                 PaymentMethod MonthlyCharges  TotalCharges  Churn
# 5180  Credit card (automatic)          64.35        4539.6     No
# 829          Electronic check          44.85        1442.6     No
# 2325         Electronic check          19.95          82.9     No
# 3906         Electronic check          78.80          78.8    Yes
# 356          Electronic check          54.10         889.0     No
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns 
#         = ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['TotalCharges'].mean()/(df['Churn'].value_counts().Yes/df['Churn'].value_counts().sum())
# Out:
# 8604.218836195429

# %%
df.sample(15)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4552  1385-TQOZW  Female              0      No         No       9
# 3497  9799-CAYJJ  Female              1     Yes         No       2
# 5981  8577-QSOCG  Female              0     Yes        Yes      38
# 1565  6968-GMKPR  Female              0      No         No      55
# 2502  9067-YGSCA  Female              0      No         No      70
# 4571  0599-XNYDO  Female              0     Yes         No      20
# 4134  3005-TYFRD  Female              0     Yes         No      55
# 1741  0106-GHRQR    Male              0      No         No      16
# 243   9058-HRZSV  Female              1     Yes         No      65
# 2758  2439-QKJUL    Male              0      No         No       5
# 1192  1579-KLYDT    Male              0      No         No       7
# 3155  4962-CHQPW    Male              0      No        Yes      29
# 6084  5119-KEPFY    Male              0     Yes         No      36
# 1655  7963-GQRMY  Female              0     Yes        Yes       3
# 1090  9036-CSKBW  Female              0      No         No      51
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 4552          Yes            No              No  No internet service  ...
# 3497          Yes            No     Fiber optic                   No  ...
# 5981          Yes            No              No  No internet service  ...
# 1565          Yes            No     Fiber optic                   No  ...
# 2502          Yes           Yes              No  No internet service  ...
# 4571          Yes            No     Fiber optic                   No  ...
# 4134          Yes           Yes     Fiber optic                   No  ...
# 1741          Yes           Yes             DSL                   No  ...
# 243           Yes            No     Fiber optic                  Yes  ...
# 2758          Yes            No              No  No internet service  ...
# 1192          Yes           Yes     Fiber optic                   No  ...
# 3155          Yes            No              No  No internet service  ...
# 6084          Yes           Yes     Fiber optic                   No  ...
# 1655          Yes            No             DSL                   No  ...
# 1090          Yes           Yes     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 4552  No internet service  No internet service  No internet service
# 3497                   No                   No                   No
# 5981  No internet service  No internet service  No internet service
# 1565                  Yes                   No                   No
# 2502  No internet service  No internet service  No internet service
# 4571                   No                   No                   No
# 4134                  Yes                   No                  Yes
# 1741                  Yes                   No                   No
# 243                   Yes                   No                   No
# 2758  No internet service  No internet service  No internet service
# 1192                  Yes                   No                  Yes
# 3155  No internet service  No internet service  No internet service
# 6084                   No                   No                  Yes
# 1655                   No                   No                   No
# 1090                  Yes                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 4552  No internet service  Month-to-month              Yes
# 3497                   No  Month-to-month              Yes
# 5981  No internet service        Two year              Yes
# 1565                   No  Month-to-month              Yes
# 2502  No internet service        One year               No
# 4571                   No  Month-to-month              Yes
# 4134                  Yes  Month-to-month              Yes
# 1741                  Yes  Month-to-month              Yes
# 243                   Yes  Month-to-month               No
# 2758  No internet service  Month-to-month               No
# 1192                   No  Month-to-month              Yes
# 3155  No internet service        One year               No
# 6084                  Yes  Month-to-month              Yes
# 1655                   No  Month-to-month               No
# 1090                  Yes        One year               No
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 4552    Credit card (automatic)          20.45        147.55     No
# 3497           Electronic check          69.30        153.80     No
# 5981               Mailed check          20.20        746.05     No
# 1565           Electronic check          81.55       4509.50     No
# 2502    Credit card (automatic)          26.05       1856.40     No
# 4571  Bank transfer (automatic)          69.80       1540.35     No
# 4134    Credit card (automatic)         103.65       5676.65     No
# 1741  Bank transfer (automatic)          71.40       1212.10     No
# 243            Electronic check          94.40       6126.15     No
# 2758               Mailed check          20.25        109.80     No
# 1192           Electronic check          90.45        593.45    Yes
# 3155               Mailed check          19.85        535.05     No
# 6084  Bank transfer (automatic)          95.00       3440.25     No
# 1655               Mailed check          44.30        134.50    Yes
# 1090  Bank transfer (automatic)         107.45       5680.90     No
#
# [15 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
df[['tenure', 'MonthlyCharges', 'TotalCharges']].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7032.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2266.771362
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.850000   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
df['tenure'].loc[df['Churn']=='Yes'].hist(bins = 5);

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df.groupby(['Churn', 'gender'])['gender'].count() #sometimes sum() is count()!!!
# Out:
# Churn  gender
# No     Female    2549
#        Male      2625
# Yes    Female     939
#        Male       930
# Name: gender, dtype: int64

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3899  9278-VZKCD  Female              1     Yes         No      52
# 4788  9102-OXKFY    Male              0      No         No      59
# 1916  4720-VSTSI  Female              0      No         No      44
# 6674  6258-NGCNG    Male              0      No         No       7
# 6141  5385-SUIRI    Male              1     Yes         No      52
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 3899          Yes           Yes     Fiber optic                  Yes  ...
# 4788          Yes           Yes             DSL                   No  ...
# 1916          Yes           Yes     Fiber optic                   No  ...
# 6674          Yes           Yes              No  No internet service  ...
# 6141          Yes           Yes     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 3899                  Yes                   No                  Yes
# 4788                  Yes                   No                   No
# 1916                  Yes                   No                   No
# 6674  No internet service  No internet service  No internet service
# 6141                  Yes                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 3899                  Yes  Month-to-month              Yes
# 4788                   No        Two year               No
# 1916                   No  Month-to-month              Yes
# 6674  No internet service  Month-to-month               No
# 6141                  Yes  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 3899           Electronic check         109.10       5647.95     No
# 4788    Credit card (automatic)          54.15       3116.15     No
# 1916  Bank transfer (automatic)          84.80       3862.55    Yes
# 6674               Mailed check          23.50        173.00     No
# 6141           Electronic check         104.20       5568.35    Yes
#
# [5 rows x 21 columns]

# %%
def gender_enc(string):
    if string == 'Female':
        return 0
    else:
        return 1

gender_enc('Male')
# Out:
# 1

# %%
df['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
df['gender'] = df['gender'].apply(lambda row: gender_enc(row)) #axis = 1 means down column(s), axis = 0 means across row(s)
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4551  5827-MWCZK       1              0     Yes        Yes      56
# 3601  1552-CZCLL       0              0     Yes        Yes      55
# 6146  4009-ALQFH       0              0      No         No      25
# 6744  6500-JVEGC       1              0      No         No      68
# 3209  8149-RSOUN       0              0      No         No       1
# 5078  9402-ROUMJ       0              0     Yes        Yes      67
# 5976  6907-CQGPN       1              0      No         No      29
# 2585  9624-EGDEQ       0              0      No         No      37
# 6143  5774-QPLTF       1              0     Yes        Yes      50
# 4484  7465-ZZRVX       1              0      No         No       1
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 4551          Yes               Yes     Fiber optic                   No  ...
# 3601          Yes                No              No  No internet service  ...
# 6146          Yes                No     Fiber optic                   No  ...
# 6744          Yes               Yes     Fiber optic                  Yes  ...
# 3209          Yes               Yes     Fiber optic                   No  ...
# 5078          Yes               Yes     Fiber optic                  Yes  ...
# 5976           No  No phone service             DSL                   No  ...
# 2585          Yes                No              No  No internet service  ...
# 6143          Yes                No              No  No internet service  ...
# 4484          Yes                No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 4551                   No                  Yes                  Yes
# 3601  No internet service  No internet service  No internet service
# 6146                  Yes                   No                  Yes
# 6744                  Yes                   No                  Yes
# 3209                   No                   No                  Yes
# 5078                  Yes                  Yes                   No
# 5976                   No                  Yes                   No
# 2585  No internet service  No internet service  No internet service
# 6143  No internet service  No internet service  No internet service
# 4484                   No                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 4551                   No  Month-to-month              Yes
# 3601  No internet service  Month-to-month               No
# 6146                  Yes  Month-to-month              Yes
# 6744                   No        One year               No
# 3209                  Yes  Month-to-month              Yes
# 5078                  Yes        One year              Yes
# 5976                   No  Month-to-month               No
# 2585  No internet service        Two year               No
# 6143  No internet service        One year              Yes
# 4484                   No  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 4551    Credit card (automatic)          96.95       5432.20     No
# 3601    Credit card (automatic)          20.00       1087.25     No
# 6146           Electronic check          99.50       2369.05    Yes
# 6744  Bank transfer (automatic)         101.35       7110.75     No
# 3209           Electronic check          93.85         93.85    Yes
# 5078  Bank transfer (automatic)         100.25       6689.00     No
# 5976           Electronic check          34.30       1004.75     No
# 2585               Mailed check          19.80        813.30     No
# 6143               Mailed check          20.35        938.95     No
# 4484           Electronic check          70.35         70.35     No
#
# [10 rows x 21 columns]

# %%
df['gender'].value_counts()
# Out:
# 1    3555
# 0    3488
# Name: gender, dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.describe().columns
# Out:
# Index(['gender', 'SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
cat_cols = ['Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod']
cat_cols
# Out:
# ['Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
df['Partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
for col in cat_cols:
    print(df[col].value_counts())
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: StreamingTV, dtype: int64
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
def yes_no(string):
    if string == 'Yes':
        return 1
    else:
        return 0

# %%
def service(string):
    if string == 'Yes':
        return 1
    elif string == 'No':
        return 0 
    else:
        return -1 # no internet/phone service

# %%
def internet_service(string):
    if string == 'Fiber optic':
        return 2
    elif string == 'DSL':
        return 1
    else:
        return 0

# %%
def contract(string):
    if string == 'Month-to-month':
        return 1
    elif string == 'One year':
        return 2
    else:
        return 3

# %%
def pay_meth(string):
    if string == 'Electronic check':
        return 1
    elif string == 'Mailed check':
        return 2
    elif string == 'Bank transfer (automatic)':
        return 3
    else:
        return 4

# %%
import numpy as np

# %%
f = lambda x: x + 5
f(2)
# Out:
# 7

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

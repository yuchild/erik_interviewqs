# %%
"""
Given the following dataset, calculate the average lifetime value of a customer.

    
Below are a couple of definitions to help solve the problem:
    
Lifetime value is average revenue divided by the churn rate

Churn rate is defined as the total number of churned customers / total number of customers
     
Additionally, here is code to import the relevant packages as well as the dataset shown above, 
to help get you started:
    
#Importing packages

import pandas as pd

import numpy as np
    

#Read in the dataset
    
data = pd.read_csv("https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/teleco_user_data.csv") 
    
#Convert these column types to int
    
data['TotalCharges'] = pd.to_numeric(data.TotalCharges, downcast='integer', errors='coerce')

data['MonthlyCharges'] = pd.to_numeric(data.MonthlyCharges, downcast='integer', errors='coerce')
"""

import pandas as pd
import numpy as np

# load data, done on 2021-10-18
# url = "https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/teleco_user_data.csv"
# df = pd.read_csv(url)
# df['TotalCharges'] = pd.to_numeric(df.TotalCharges, downcast='integer', errors='coerce')
# df['MonthlyCharges'] = pd.to_numeric(df.MonthlyCharges, downcast='integer', errors='coerce')
# df.to_pickle('./data/teleco_user_data.pkl')

# %%
# load data
df = pd.read_pickle('./data/teleco_user_data.pkl')
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2560  8178-EYZUO    Male              0      No         No      46
# 3397  1642-HMARX  Female              0     Yes         No      68
# 5955  7169-YWAMK    Male              0     Yes        Yes      72
# 6837  6229-LSCKB    Male              1      No         No       6
# 5107  9633-DENPU  Female              0     Yes         No      47
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2560          Yes           Yes     Fiber optic            Yes  ...
# 3397          Yes           Yes             DSL            Yes  ...
# 5955          Yes            No             DSL            Yes  ...
# 6837          Yes            No     Fiber optic             No  ...
# 5107          Yes            No             DSL             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 2560               No          No          No             Yes  Month-to-month
# 3397              Yes         Yes         Yes             Yes        Two year
# 5955               No         Yes         Yes              No        Two year
# 6837               No          No         Yes              No  Month-to-month
# 5107               No          No         Yes              No  Month-to-month
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 2560              Yes           Electronic check           93.7       4154.80
# 3397              Yes           Electronic check           91.7       6424.70
# 5955               No  Bank transfer (automatic)           68.4       4855.35
# 6837              Yes           Electronic check           79.7        497.60
# 5107              Yes  Bank transfer (automatic)           58.6       2723.40
#
#       Churn
# 2560    Yes
# 3397     No
# 5955     No
# 6837     No
# 5107     No
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns 
#         = ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['TotalCharges'].mean()/(df['Churn'].value_counts().Yes/df['Churn'].value_counts().sum())
# Out:
# 8604.218836195429

# %%
df.sample(15)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6733  4011-ARPHK    Male              0      No         No      27
# 6068  3945-GFWQL  Female              0      No        Yes      12
# 3242  3717-FDJFU    Male              0      No        Yes       5
# 2224  2528-HFYZX    Male              1     Yes         No      17
# 2037  8309-IEYJD  Female              1      No         No       1
# 5499  4631-OACRM    Male              1      No         No      15
# 1876  3946-JEWRQ    Male              0     Yes         No      47
# 4927  4774-HHGGS    Male              0     Yes         No      30
# 4143  4822-YCXMX    Male              0      No         No      25
# 4137  7777-UNYHB  Female              0     Yes        Yes      12
# 3966  8915-NNTRC    Male              0     Yes        Yes      72
# 1804  6016-LVTJQ  Female              0     Yes        Yes      34
# 3583  2292-XQWSV    Male              0     Yes        Yes      40
# 551   1352-HNSAW  Female              0     Yes        Yes      72
# 3033  5795-KTGUD  Female              0     Yes         No      68
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 6733          Yes                No             DSL                  Yes  ...
# 6068          Yes                No             DSL                   No  ...
# 3242          Yes                No              No  No internet service  ...
# 2224          Yes                No     Fiber optic                   No  ...
# 2037          Yes                No     Fiber optic                   No  ...
# 5499          Yes                No     Fiber optic                   No  ...
# 1876          Yes               Yes     Fiber optic                   No  ...
# 4927          Yes                No              No  No internet service  ...
# 4143          Yes               Yes     Fiber optic                   No  ...
# 4137          Yes                No              No  No internet service  ...
# 3966          Yes               Yes     Fiber optic                  Yes  ...
# 1804          Yes                No              No  No internet service  ...
# 3583           No  No phone service             DSL                   No  ...
# 551           Yes               Yes     Fiber optic                  Yes  ...
# 3033          Yes               Yes     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 6733                   No                   No                   No
# 6068                   No                   No                   No
# 3242  No internet service  No internet service  No internet service
# 2224                   No                   No                   No
# 2037                   No                   No                   No
# 5499                   No                   No                   No
# 1876                   No                   No                  Yes
# 4927  No internet service  No internet service  No internet service
# 4143                   No                   No                   No
# 4137  No internet service  No internet service  No internet service
# 3966                   No                  Yes                  Yes
# 1804  No internet service  No internet service  No internet service
# 3583                  Yes                  Yes                  Yes
# 551                   Yes                  Yes                  Yes
# 3033                  Yes                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 6733                   No  Month-to-month               No
# 6068                   No  Month-to-month              Yes
# 3242  No internet service        Two year               No
# 2224                   No  Month-to-month              Yes
# 2037                   No  Month-to-month              Yes
# 5499                  Yes  Month-to-month              Yes
# 1876                  Yes        One year              Yes
# 4927  No internet service        Two year               No
# 4143                  Yes  Month-to-month              Yes
# 4137  No internet service  Month-to-month              Yes
# 3966                  Yes        Two year              Yes
# 1804  No internet service  Month-to-month               No
# 3583                  Yes        One year               No
# 551                   Yes        Two year              Yes
# 3033                  Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 6733               Mailed check          50.35       1411.35     No
# 6068           Electronic check          44.55        480.60    Yes
# 3242               Mailed check          20.45        106.90     No
# 2224           Electronic check          76.45       1233.40    Yes
# 2037               Mailed check          70.60         70.60     No
# 5499           Electronic check          79.40       1156.10    Yes
# 1876    Credit card (automatic)          95.20       4563.00     No
# 4927               Mailed check          19.05        637.55     No
# 4143           Electronic check          84.80       2043.45    Yes
# 4137    Credit card (automatic)          20.10        232.40     No
# 3966    Credit card (automatic)         107.70       7919.80     No
# 1804               Mailed check          20.65        716.40     No
# 3583               Mailed check          60.30       2448.50     No
# 551   Bank transfer (automatic)         115.60       8220.40     No
# 3033  Bank transfer (automatic)         110.80       7553.60     No
#
# [15 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
df[['tenure', 'MonthlyCharges', 'TotalCharges']].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7032.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2266.771362
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.850000   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
df['tenure'].loc[df['Churn']=='Yes'].hist(bins = 5);

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df.groupby(['Churn', 'gender'])['gender'].count() #sometimes sum() is count()!!!
# Out:
# Churn  gender
# No     Female    2549
#        Male      2625
# Yes    Female     939
#        Male       930
# Name: gender, dtype: int64

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6452  9529-OFXHY    Male              0      No         No      15
# 1830  7321-KKSDU    Male              0      No        Yes      32
# 6745  5515-AKOAJ  Female              0      No         No      54
# 3520  6036-TTFYU  Female              0     Yes         No      16
# 1871  3062-ICYZQ  Female              0     Yes        Yes      51
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 6452          Yes           Yes     Fiber optic                  Yes  ...
# 1830          Yes            No              No  No internet service  ...
# 6745          Yes           Yes     Fiber optic                   No  ...
# 3520          Yes            No              No  No internet service  ...
# 1871          Yes           Yes     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 6452                   No                   No                  Yes
# 1830  No internet service  No internet service  No internet service
# 6745                   No                  Yes                  Yes
# 3520  No internet service  No internet service  No internet service
# 1871                   No                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 6452                   No  Month-to-month              Yes
# 1830  No internet service        Two year               No
# 6745                  Yes  Month-to-month              Yes
# 3520  No internet service  Month-to-month               No
# 1871                  Yes  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 6452  Bank transfer (automatic)          87.75       1242.20     No
# 1830               Mailed check          20.50        696.80     No
# 6745           Electronic check         100.10       5440.90    Yes
# 3520               Mailed check          19.60        314.45     No
# 1871           Electronic check          93.80       4539.35     No
#
# [5 rows x 21 columns]

# %%
def gender_enc(string):
    if string == 'Female':
        return 0
    else:
        return 1

gender_enc('Male')
# Out:
# 1

# %%
df['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
df['gender'] = df['gender'].apply(lambda row: gender_enc(row)) #axis = 1 means down column(s), axis = 0 means across row(s)
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3388  8498-XXGWA       0              0     Yes         No      65
# 5328  0334-ZFJSR       0              0     Yes         No      55
# 842   1038-ZAGBI       0              0     Yes        Yes      12
# 2123  8819-IMISP       1              0      No         No      31
# 61    1215-FIGMP       1              0      No         No      60
# 4771  1678-FYZOW       0              0      No         No       3
# 2640  4391-LNRXK       1              0      No         No      22
# 2501  6585-WCEWR       1              0     Yes        Yes      72
# 4626  0929-PECLO       0              1      No         No      63
# 3746  4806-HIPDW       0              0     Yes         No       1
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 3388          Yes            No             DSL                  Yes  ...
# 5328          Yes           Yes             DSL                  Yes  ...
# 842           Yes            No              No  No internet service  ...
# 2123          Yes           Yes     Fiber optic                   No  ...
# 61            Yes           Yes     Fiber optic                   No  ...
# 4771          Yes            No     Fiber optic                   No  ...
# 2640          Yes            No     Fiber optic                   No  ...
# 2501          Yes            No              No  No internet service  ...
# 4626          Yes           Yes     Fiber optic                   No  ...
# 3746          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 3388                  Yes                   No                   No
# 5328                   No                  Yes                   No
# 842   No internet service  No internet service  No internet service
# 2123                   No                   No                   No
# 61                     No                   No                  Yes
# 4771                   No                   No                  Yes
# 2640                  Yes                  Yes                   No
# 2501  No internet service  No internet service  No internet service
# 4626                  Yes                   No                   No
# 3746                   No                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 3388                   No  Month-to-month              Yes
# 5328                   No        One year              Yes
# 842   No internet service        One year               No
# 2123                   No  Month-to-month              Yes
# 61                     No  Month-to-month              Yes
# 4771                   No  Month-to-month              Yes
# 2640                  Yes  Month-to-month              Yes
# 2501  No internet service        Two year               No
# 4626                  Yes  Month-to-month              Yes
# 3746                   No  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 3388               Mailed check          55.15       3673.15     No
# 5328    Credit card (automatic)          66.05       3462.10     No
# 842   Bank transfer (automatic)          19.80        229.60    Yes
# 2123           Electronic check          80.45       2429.10     No
# 61    Bank transfer (automatic)          89.90       5450.70     No
# 4771           Electronic check          79.40        244.65    Yes
# 2640  Bank transfer (automatic)          94.95       2142.80     No
# 2501           Electronic check          20.35       1354.40     No
# 4626  Bank transfer (automatic)          89.60       5538.80     No
# 3746           Electronic check          68.95         68.95    Yes
#
# [10 rows x 21 columns]

# %%
df['gender'].value_counts()
# Out:
# 1    3555
# 0    3488
# Name: gender, dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.describe().columns
# Out:
# Index(['gender', 'SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
cat_cols = ['Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod']
cat_cols
# Out:
# ['Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
df['Partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
for col in cat_cols:
    print(df[col].value_counts())
    print()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
#
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64
#
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64
#
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64
#
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64
#
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64
#
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64
#
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64
#
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64
#
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: StreamingTV, dtype: int64
#
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64
#
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64
#
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64
#
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
def yes_no(string):
    if string == 'Yes':
        return 1
    else:
        return 0

# %%
def service(string):
    if string == 'Yes':
        return 1
    elif string == 'No':
        return 0 
    else:
        return -1 # no internet/phone service

# %%
def internet_service(string):
    if string == 'Fiber optic':
        return 2
    elif string == 'DSL':
        return 1
    else:
        return 0

# %%
def contract(string):
    if string == 'Month-to-month':
        return 1
    elif string == 'One year':
        return 2
    else:
        return 3

# %%
def pay_meth(string):
    if string == 'Electronic check':
        return 1
    elif string == 'Mailed check':
        return 2
    elif string == 'Bank transfer (automatic)':
        return 3
    else:
        return 4

# %%
import numpy as np

# %%
f = lambda x: x + 5
f(2)
# Out:
# 7

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
# change columns with yes or no categories
yes_no_ = ['Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']
for col in yes_no_:
    df[col] = df[col].apply(lambda row: yes_no(row))

# change columns with internet service categories
internet_service_ = ['InternetService']
for col in internet_service_:
    df[col] =  df[col].apply(lambda row: internet_service(row))

# change columns with yes, no, or no internet or phone categories
service_ = ['MultipleLines'
            , 'OnlineSecurity'
            , 'OnlineBackup'
            , 'DeviceProtection'
            , 'TechSupport'
            , 'StreamingTV'
            , 'StreamingMovies']
for col in service_:
    df[col] = df[col].apply(lambda row: service(row))

# change columns with contract categories
contract_ = ['Contract']
for col in contract_:
    df[col] = df[col].apply(lambda row: contract(row))

# change columns with payment categories
pay_meth_ = ['PaymentMethod']
for col in pay_meth_:
    df[col] = df[col].apply(lambda row: pay_meth(row))
    
df.sample(15)
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 3142  4892-VLANZ       1              0        0           0       1
# 4866  3688-FTHLT       0              0        0           0      16
# 5432  1597-FZREH       0              0        0           0       2
# 5832  6017-PPLPX       1              0        1           1      20
# 371   0259-GBZSH       1              0        0           0       2
# 6431  3266-FTKHB       1              0        0           0      17
# 5867  2428-HYUNX       1              1        1           0      44
# 6057  4003-FUSHP       1              0        0           0      19
# 1799  9172-ANCRX       0              0        0           0      10
# 6646  8249-THVEC       1              0        1           1      51
# 5973  2324-EFHVG       1              0        0           0      64
# 6527  7551-DACSP       1              0        1           1       6
# 3692  7159-FVYPK       0              0        1           1       3
# 4019  6615-NGGZJ       1              0        0           0      14
# 327   5804-LEPIM       0              1        0           0       2
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 3142             1              0                0              -1  ...
# 4866             1              1                1               0  ...
# 5432             1              0                1               0  ...
# 5832             1              0                2               0  ...
# 371              1              1                2               0  ...
# 6431             1              0                0              -1  ...
# 5867             1              0                0              -1  ...
# 6057             1              0                1               0  ...
# 1799             1              1                2               1  ...
# 6646             1              0                0              -1  ...
# 5973             1              1                2               0  ...
# 6527             1              0                1               0  ...
# 3692             1              1                1               0  ...
# 4019             1              1                2               0  ...
# 327              1              0                2               0  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 3142                -1           -1           -1               -1         1
# 4866                 0            0            0                1         1
# 5432                 1            1            1                1         1
# 5832                 0            0            0                0         1
# 371                  0            0            1                0         1
# 6431                -1           -1           -1               -1         3
# 5867                -1           -1           -1               -1         3
# 6057                 0            1            1                0         1
# 1799                 0            0            1                1         1
# 6646                -1           -1           -1               -1         2
# 5973                 1            0            1                1         3
# 6527                 1            0            0                0         1
# 3692                 1            0            1                0         1
# 4019                 0            0            1                1         1
# 327                  0            0            0                0         1
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 3142                 0              2           19.80         19.80    Yes
# 4866                 1              3           63.05       1067.05     No
# 5432                 0              1           76.40        160.80    Yes
# 5832                 1              1           70.45       1470.95    Yes
# 371                  1              1           85.65        181.50    Yes
# 6431                 0              2           19.15        343.45     No
# 5867                 1              4           19.35        847.25     No
# 6057                 1              4           61.55       1093.20     No
# 1799                 1              1           98.70        973.25    Yes
# 6646                 0              2           19.40        997.75     No
# 5973                 1              3          104.40       6692.65     No
# 6527                 1              2           55.30        324.25    Yes
# 3692                 1              3           69.15        235.00     No
# 4019                 1              1          100.55       1415.55    Yes
# 327                  1              1           70.35        139.05    Yes
#
# [15 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
#  16  PaperlessBilling  7043 non-null   int64
#  17  PaymentMethod     7043 non-null   int64
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(17), object(2)
# memory usage: 1.1+ MB

# %%
df['TotalCharges'].loc[df['TotalCharges'].isnull()] # np.null is from numpy
# Out:
# 488    NaN
# 753    NaN
# 936    NaN
# 1082   NaN
# 1340   NaN
# 3331   NaN
# 3826   NaN
# 4380   NaN
# 5218   NaN
# 6670   NaN
# 6754   NaN
# Name: TotalCharges, dtype: float64

# %%
# df.dropna(axis=0, inplace=True) # delete the rows 
df.fillna(df['TotalCharges'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
#  16  PaperlessBilling  7043 non-null   int64
#  17  PaymentMethod     7043 non-null   int64
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(17), object(2)
# memory usage: 1.1+ MB

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['Churn'] = df['Churn'].apply(lambda row: yes_no(row))
df['Churn'].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
#  16  PaperlessBilling  7043 non-null   int64
#  17  PaymentMethod     7043 non-null   int64
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   float64
#  20  Churn             7043 non-null   int64
# dtypes: float64(2), int64(18), object(1)
# memory usage: 1.1+ MB

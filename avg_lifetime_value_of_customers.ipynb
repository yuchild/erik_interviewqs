# %%
"""
Given the following dataset, calculate the average lifetime value of a customer.

    
Below are a couple of definitions to help solve the problem:
    
Lifetime value is average revenue divided by the churn rate

Churn rate is defined as the total number of churned customers / total number of customers
     
Additionally, here is code to import the relevant packages as well as the dataset shown above, 
to help get you started:
    
#Importing packages

import pandas as pd

import numpy as np
    

#Read in the dataset
    
data = pd.read_csv("https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/teleco_user_data.csv") 
    
#Convert these column types to int
    
data['TotalCharges'] = pd.to_numeric(data.TotalCharges, downcast='integer', errors='coerce')

data['MonthlyCharges'] = pd.to_numeric(data.MonthlyCharges, downcast='integer', errors='coerce')
"""

import pandas as pd
import numpy as np

# load data, done on 2021-10-18
# url = "https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/teleco_user_data.csv"
# df = pd.read_csv(url)
# df['TotalCharges'] = pd.to_numeric(df.TotalCharges, downcast='integer', errors='coerce')
# df['MonthlyCharges'] = pd.to_numeric(df.MonthlyCharges, downcast='integer', errors='coerce')
# df.to_pickle('./data/teleco_user_data.pkl')

# %%
# load data
df = pd.read_pickle('./data/teleco_user_data.pkl')
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2191  3988-RQIXO  Female              1      No         No       1
# 473   4104-PVRPS    Male              0     Yes         No      24
# 885   4661-NJEUX    Male              0      No         No       1
# 503   7803-XOCCZ  Female              0     Yes        Yes      52
# 6157  6776-TLWOI    Male              0      No         No       3
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 2191          Yes            No     Fiber optic                   No  ...
# 473           Yes            No             DSL                  Yes  ...
# 885           Yes            No              No  No internet service  ...
# 503           Yes            No     Fiber optic                  Yes  ...
# 6157          Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns 
#         = ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['TotalCharges'].mean()/(df['Churn'].value_counts().Yes/df['Churn'].value_counts().sum())
# Out:
# 8604.218836195429

# %%
df.sample(15)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6826  7976-CICYS    Male              0      No         No       4
# 6088  3063-QFSZL  Female              0      No         No       1
# 3518  8393-JMVMB    Male              0      No         No       1
# 6656  4779-ZGICK    Male              0     Yes        Yes      48
# 3348  2172-EJXVF  Female              1      No         No      71
# 1494  2667-WYLWJ  Female              0     Yes        Yes       8
# 2193  6922-NCEDI    Male              0      No        Yes      56
# 2679  7341-LXCAF    Male              0     Yes         No       4
# 4761  8224-KDLKN    Male              0     Yes        Yes      72
# 5050  7762-URZQH    Male              0     Yes         No      66
# 1190  6807-SIWJI    Male              0      No         No      38
# 625   3003-CMDUU  Female              0     Yes         No      25
# 1779  5091-HFAZW  Female              0      No         No       2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df[['tenure', 'MonthlyCharges', 'TotalCharges']].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7032.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2266.771362
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.850000   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
df['tenure'].loc[df['Churn']=='Yes'].hist(bins = 5);

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df.groupby(['Churn', 'gender'])['gender'].count() #sometimes sum() is count()!!!
# Out:
# Churn  gender
# No     Female    2549
#        Male      2625
# Yes    Female     939
#        Male       930
# Name: gender, dtype: int64

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5092  5774-XZTQC  Female              0     Yes        Yes       7
# 646   0887-HJGAR    Male              0      No         No       1
# 1792  8401-EMUWF    Male              0     Yes        Yes      42
# 2996  6620-JDYNW  Female              0      No         No      18
# 165   6345-FZOQH    Male              0     Yes         No      69
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 5092          Yes            No              No  No internet service  ...
# 646           Yes            No             DSL                   No  ...
# 1792          Yes           Yes             DSL                  Yes  ...
# 2996          Yes           Yes             DSL                  Yes  ...
# 165           Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
def gender_enc(string):
    if string == 'Female':
        return 0
    else:
        return 1

gender_enc('Male')
# Out:
# 1

# %%
df['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
df['gender'] = df['gender'].apply(lambda row: gender_enc(row)) #axis = 1 means down column(s), axis = 0 means across row(s)
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 181   6582-OIVSP       0              0      No         No       1
# 4249  7919-ZODZZ       0              0     Yes        Yes      10
# 6463  0872-CASZJ       1              0     Yes         No      59
# 6842  5546-QUERU       1              0      No         No      13
# 1110  0343-QLUZP       1              0      No         No      60
# 3563  6741-EGCBI       1              1      No         No      30
# 3320  2195-VVRJF       1              1     Yes         No      18
# 6220  6434-TTGJP       1              0     Yes        Yes      10
# 6905  4459-BBGHE       1              0      No        Yes      30
# 6621  6762-NSODU       0              0     Yes        Yes      46
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 181           Yes                No             DSL                   No  ...
# ...

# %%
df['gender'].value_counts()
# Out:
# 1    3555
# 0    3488
# Name: gender, dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.describe().columns
# Out:
# Index(['gender', 'SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
cat_cols = ['Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod']
cat_cols
# Out:
# ['Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
df['Partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
for col in cat_cols:
    print(df[col].value_counts())
    print()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
#
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64
#
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64
#
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64
#
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64
#
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64
#
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64
#
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64
#
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64
#
# No                     2810
# Yes                    2707
# ...

# %%
def yes_no(string):
    if string == 'Yes':
        return 1
    else:
        return 0

# %%
def service(string):
    if string == 'Yes':
        return 1
    elif string == 'No':
        return 0 
    else:
        return -1 # no internet/phone service

# %%
def internet_service(string):
    if string == 'Fiber optic':
        return 2
    elif string == 'DSL':
        return 1
    else:
        return 0

# %%
def contract(string):
    if string == 'Month-to-month':
        return 1
    elif string == 'One year':
        return 2
    else:
        return 3

# %%
def pay_meth(string):
    if string == 'Electronic check':
        return 1
    elif string == 'Mailed check':
        return 2
    elif string == 'Bank transfer (automatic)':
        return 3
    else:
        return 4

# %%
import numpy as np

# %%
f = lambda x: x + 5
f(2)
# Out:
# 7

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
# change columns with yes or no categories
yes_no_ = ['Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']
for col in yes_no_:
    df[col] = df[col].apply(lambda row: yes_no(row))

# change columns with internet service categories
internet_service_ = ['InternetService']
for col in internet_service_:
    df[col] =  df[col].apply(lambda row: internet_service(row))

# change columns with yes, no, or no internet or phone categories
service_ = ['MultipleLines'
            , 'OnlineSecurity'
            , 'OnlineBackup'
            , 'DeviceProtection'
            , 'TechSupport'
            , 'StreamingTV'
            , 'StreamingMovies']
for col in service_:
    df[col] = df[col].apply(lambda row: service(row))

# change columns with contract categories
contract_ = ['Contract']
for col in contract_:
    df[col] = df[col].apply(lambda row: contract(row))

# change columns with payment categories
pay_meth_ = ['PaymentMethod']
for col in pay_meth_:
    df[col] = df[col].apply(lambda row: pay_meth(row))
    
df.sample(15)
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 575   9548-LIGTA       1              0        1           0      61
# 3086  3853-LYGAM       1              0        0           0      17
# 4505  6917-FIJHC       0              0        1           0      72
# 3003  2640-PMGFL       1              0        0           1      27
# 6421  2999-AANRQ       0              0        0           0      21
# 6350  3407-QGWLG       1              0        0           1       3
# 6468  2599-CZABP       1              0        1           0      14
# 3478  7673-LPRNY       0              0        0           0      23
# 6320  8845-LWKGE       0              0        1           1      30
# 1077  4361-BKAXE       0              0        0           0      41
# 2091  8957-THMOA       0              0        0           1      50
# 6145  5010-IPEAQ       0              0        1           1      67
# 5245  5902-WBLSE       0              0        1           1      70
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
# ...

# %%
df['TotalCharges'].loc[df['TotalCharges'].isnull()] # np.null is from numpy
# Out:
# 488    NaN
# 753    NaN
# 936    NaN
# 1082   NaN
# 1340   NaN
# 3331   NaN
# 3826   NaN
# 4380   NaN
# 5218   NaN
# 6670   NaN
# 6754   NaN
# Name: TotalCharges, dtype: float64

# %%
# df.dropna(axis=0, inplace=True) # delete the rows 
df.fillna(df['TotalCharges'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
# ...

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['Churn'] = df['Churn'].apply(lambda row: yes_no(row))
df['Churn'].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
# ...

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# %%
rfc = RandomForestClassifier(random_state=42
                             , n_jobs=-1
                            )
rfr = RandomForestRegressor(random_state=42
                            , n_jobs=-1
                           )

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 6336  8647-SDTWQ       1              0        1           1      57
# 3102  0516-WJVXC       0              0        0           0       5
# 5938  9971-ZWPBF       1              1        1           1      34
# 2088  6784-XYJAE       0              0        0           0      36
# 4108  2650-GYRYL       1              0        1           1      33
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 6336             1              1                2               0  ...
# 3102             1              0                1               1  ...
# 5938             1              1                2               0  ...
# 2088             1              1                1               0  ...
# 4108             1              0                0              -1  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %%
int(df.shape[0] * 0.85)
# Out:
# 5986

# %%
split = int(df.shape[0] * 0.85)

df.drop(columns=['customerID'], inplace=True)
df.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 1980       1              0        0           0      10             1
# 3801       0              1        0           0      18             1
# 2801       0              0        1           1      62             1
# 3706       1              0        0           0      26             1
# 5004       0              0        1           0      64             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 1980              1                2               0             1
# 3801              1                2               0             1
# 2801              1                2               0             1
# 3706              1                2               0             0
# 5004              1                2               0             1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %%
df_train = df[:split].copy()
df_test = df[split:].copy()

# %%
X_train = df_train.drop(columns=['Churn']).copy()
y_train = df_train['Churn'].copy()

X_test = df_test.drop(columns=['Churn']).copy()
y_test = df_test['Churn'].copy()

# %%
rfc.fit(X_train, y_train) # fit the training set with the RandomForestClassifier object rfc
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
df.iloc[-1]
# Out:
# gender                 1.00
# SeniorCitizen          0.00
# Partner                0.00
# Dependents             0.00
# tenure                66.00
# PhoneService           1.00
# MultipleLines          0.00
# InternetService        2.00
# OnlineSecurity         1.00
# OnlineBackup           0.00
# DeviceProtection       1.00
# TechSupport            1.00
# StreamingTV            1.00
# StreamingMovies        1.00
# Contract               3.00
# PaperlessBilling       1.00
# PaymentMethod          3.00
# MonthlyCharges       105.65
# TotalCharges        6844.50
# Churn                  0.00
# Name: 7042, dtype: float64

# %%
df.tail(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 7040             -1                1               1             0
# 7041              1                2               0             0
# 7042              0                2               1             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 7040                 0            0            0                0         1
# 7041                 0            0            0                0         1
# 7042                 1            1            1                1         3
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# ...

# %%
X_test.iloc[-1].values
# Out:
# array([1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 6.6000e+01,
#        1.0000e+00, 0.0000e+00, 2.0000e+00, 1.0000e+00, 0.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 3.0000e+00,
#        1.0000e+00, 3.0000e+00, 1.0565e+02, 6.8445e+03])

# %%
X_test.iloc[-1].values.reshape(1,-1)
# Out:
# array([[1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 6.6000e+01,
#         1.0000e+00, 0.0000e+00, 2.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 3.0000e+00,
#         1.0000e+00, 3.0000e+00, 1.0565e+02, 6.8445e+03]])

# %%
rfc.predict(X_test.iloc[-1].values.reshape(1,-1))
# Out:
# array([0])

# %%
rfc.predict(X_test.iloc[-2].values.reshape(1,-1))
# Out:
# array([1])

# %%
rfc.predict(X_test.iloc[-3].values.reshape(1,-1))
# Out:
# array([0])

# %%
rfc.predict(X_test)
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
y_test
# Out:
# 5986    0
# 5987    0
# 5988    0
# 5989    1
# 5990    0
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 1057, dtype: int64

# %%
correct=0
incorrect=0

for i in range(len(y_test)):
    if rfc.predict(X_test.iloc[i].values.reshape(1,-1)) == y_test.iloc[i]:
        correct += 1
    else:
        incorrect += 1

# %%
correct
# Out:
# 841

# %%
incorrect
# Out:
# 216

# %%
correct / (correct + incorrect)
# Out:
# 0.7956480605487228

# %%
#===============
#STOP 2021-10-29
#===============

# %%
# see which features are important
# rfc.feature_importances_

# %%
# feature engineering, normalizing
df.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 5068       0              0        1           0      71             1
# 5267       1              1        1           0       9             1
# 3356       0              0        1           1       4             1
# 500        1              0        0           0      34             1
# 1015       1              0        1           1      12             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 5068              0                0              -1            -1
# 5267              0                0              -1            -1
# 3356              1                1               0             0
# 500               1                2               1             1
# 1015              0                1               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %%
# normalize tenure
tenure_min = df['tenure'].min()
tenure_max = df['tenure'].max()
tenure_range = tenure_max - tenure_min

df['tenure'] = (df['tenure'] - tenure_min) / tenure_range
df.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 4967       0              0        0           0  0.041667             1
# 6950       0              0        1           1  0.069444             1
# 2837       0              0        0           0  0.013889             1
# 6034       0              0        0           0  0.097222             1
# 2622       1              1        1           1  0.388889             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 4967              1                1               0             0
# 6950              0                1               1             0
# 2837              0                0              -1            -1
# 6034              0                0              -1            -1
# 2622              1                1               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %%
# normalize MonthlyCharges
mc_min = df['MonthlyCharges'].min()
mc_max = df['MonthlyCharges'].max()
mc_range = mc_max - mc_min

df['MonthlyCharges'] = (df['MonthlyCharges'] - mc_min) / mc_range
df.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 3813       1              0        1           1  0.958333             1
# 2892       1              0        0           0  0.013889             1
# 3052       1              0        1           0  0.513889             1
# 5805       1              1        1           0  0.263889             1
# 3934       0              0        0           1  0.138889             0
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 3813              1                2               0             1
# 2892              0                0              -1            -1
# 3052              1                1               1             0
# 5805              0                1               1             0
# 3934             -1                1               1             1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %%
# normalize TotalCharges
tc_min = df['TotalCharges'].min()
tc_max = df['TotalCharges'].max()
tc_range = tc_max - tc_min

df['TotalCharges'] = (df['TotalCharges'] - tc_min) / tc_range
df.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 620        1              1        1           1  0.138889             0
# 2794       0              0        0           0  0.388889             1
# 5116       1              0        0           0  0.013889             1
# 6858       0              0        1           1  0.347222             1
# 6053       0              0        0           1  0.597222             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 620              -1                1               0             0
# 2794              0                1               1             1
# 5116              0                2               0             0
# 6858              1                2               0             0
# 6053              1                0              -1            -1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %%
train_df_norm = df[:split]
test_df_norm = df[split:]

X_train = train_df_norm.drop(columns=['Churn']).copy()
X_test = test_df_norm.drop(columns=['Churn']).copy()
y_train = train_df_norm['Churn'].copy()
y_test = train_df_norm['Churn'].copy()

# %%
rfc_norm = rfc.fit(X_train, y_train)

# %%
rfc_norm.predict(X_test.iloc[-1].values.reshape(1,-1))
# Out:
# array([0])

# %%
y_test.iloc[-1]
# Out:
# 0

# %%
correct_norm = 0
incorrect_norm = 0

for i in range(len(X_test)):
    if rfc_norm.predict(X_test.iloc[i].values.reshape(1,-1)) == y_test.iloc[i]:
        correct_norm += 1
    else:
        incorrect_norm += 1

# %%
correct_norm / (correct_norm + incorrect_norm)
# Out:
# 0.6556291390728477

# %%
rfc_norm.feature_importances_
# Out:
# array([0.02715609, 0.02103392, 0.02215622, 0.01937451, 0.16371163,
#        0.00408219, 0.02260997, 0.04390206, 0.0243149 , 0.02746238,
#        0.0235934 , 0.02491997, 0.02149133, 0.02103603, 0.07796486,
#        0.02574194, 0.06081018, 0.17648219, 0.19215622])

# %%
X_test.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges'],
#       dtype='object')

# %%
top_features_ = ['tenure', 'InternetService', 'Contract', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
train_df_normal_short = df[top_features_].iloc[:split].copy()
test_df_normal_short = df[top_features_].iloc[split:].copy()

X_train = train_df_normal_short[top_features_[:-1]]
y_train = train_df_normal_short[top_features_[-1]]

X_test = test_df_normal_short[top_features_[:-1]]
y_test = test_df_normal_short[top_features_[-1]]

# %%
rfc_norm_short = rfc.fit(X_train, y_train)

# %%
rfc_norm_short.predict(X_test.iloc[-1].values.reshape(1,-1))
# Out:
# array([0])

# %%
y_test.iloc[-1]
# Out:
# 0

# %%
correct_norm = 0
incorrect_norm = 0

for i in range(len(X_test)):
    if rfc_norm_short.predict(X_test.iloc[i].values.reshape(1,-1)) == y_test.iloc[i]:
        correct_norm += 1
    else:
        incorrect_norm += 1

# %%
correct_norm / (correct_norm + incorrect_norm)
# Out:
# 0.7776726584673604

# %%
# use rfc without transformations

# %%
df = pd.read_pickle('./data/teleco_user_data.pkl')
df_model = df[top_features_]
split = int(len(df_model)*0.85)
train = df_model[:split].copy()
test = df_model[split:].copy()
X_train = train.drop(columns=['Churn']).copy()
y_train = train['Churn'].copy()
X_test = test.drop(columns=['Churn']).copy()
y_test = test['Churn'].copy()
# rfc_raw = rfc.fit(X_train, y_train)
#rfc_predict(X_test.iloc[-1].values.reshape(1,-1))

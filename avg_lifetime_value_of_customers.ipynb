# %%
"""
Given the following dataset, calculate the average lifetime value of a customer.

    
Below are a couple of definitions to help solve the problem:
    
Lifetime value is average revenue divided by the churn rate

Churn rate is defined as the total number of churned customers / total number of customers
     
Additionally, here is code to import the relevant packages as well as the dataset shown above, 
to help get you started:
    
#Importing packages

import pandas as pd

import numpy as np
    

#Read in the dataset
    
data = pd.read_csv("https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/teleco_user_data.csv") 
    
#Convert these column types to int
    
data['TotalCharges'] = pd.to_numeric(data.TotalCharges, downcast='integer', errors='coerce')

data['MonthlyCharges'] = pd.to_numeric(data.MonthlyCharges, downcast='integer', errors='coerce')
"""

import pandas as pd
import numpy as np

# load data, done on 2021-10-18
# url = "https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/teleco_user_data.csv"
# df = pd.read_csv(url)
# df['TotalCharges'] = pd.to_numeric(df.TotalCharges, downcast='integer', errors='coerce')
# df['MonthlyCharges'] = pd.to_numeric(df.MonthlyCharges, downcast='integer', errors='coerce')
# df.to_pickle('./data/teleco_user_data.pkl')

# %%
# load data
df = pd.read_pickle('./data/teleco_user_data.pkl')
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 642   0970-ETWGE    Male              0      No         No       1
# 2096  0761-AETCS  Female              0      No         No       1
# 1258  5529-GIBVH  Female              0      No         No      47
# 3657  8450-LUGUK  Female              0     Yes        Yes      37
# 1526  2984-AFWNC  Female              0      No         No       3
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 642           Yes            No     Fiber optic                   No  ...
# 2096          Yes            No              No  No internet service  ...
# 1258          Yes            No              No  No internet service  ...
# 3657          Yes           Yes              No  No internet service  ...
# 1526          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 642                    No                   No                  Yes
# 2096  No internet service  No internet service  No internet service
# 1258  No internet service  No internet service  No internet service
# 3657  No internet service  No internet service  No internet service
# 1526                   No                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 642                   Yes  Month-to-month              Yes
# 2096  No internet service  Month-to-month               No
# 1258  No internet service        Two year               No
# 3657  No internet service        Two year              Yes
# 1526                  Yes  Month-to-month               No
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 642            Electronic check          89.55         89.55    Yes
# 2096           Electronic check          19.30         19.30    Yes
# 1258               Mailed check          20.15       1046.20     No
# 3657  Bank transfer (automatic)          24.10        861.85     No
# 1526           Electronic check          95.40        293.15     No
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns 
#         = ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['TotalCharges'].mean()/(df['Churn'].value_counts().Yes/df['Churn'].value_counts().sum())
# Out:
# 8604.218836195429

# %%
df.sample(15)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1110  0343-QLUZP    Male              0      No         No      60
# 5938  9971-ZWPBF    Male              1     Yes        Yes      34
# 4488  3714-JTVOV  Female              1     Yes         No      42
# 212   7157-SMCFK    Male              0      No        Yes      61
# 1742  5318-IXUZF  Female              0      No         No       2
# 589   0795-LAFGP    Male              0     Yes        Yes      71
# 1608  2387-KDZQY    Male              0      No         No      17
# 2873  0148-DCDOS    Male              0      No         No      25
# 1083  9878-TNQGW    Male              0      No         No       2
# 5794  1162-ECVII    Male              1     Yes         No      72
# 2889  9830-ECLEN    Male              0     Yes        Yes      58
# 1452  0222-CNVPT    Male              1      No         No      52
# 5949  8756-RDDLT  Female              0      No         No      68
# 2381  7649-PHJVR    Male              0      No         No      11
# 1515  1921-KYSAY  Female              0      No         No      41
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1110           No  No phone service             DSL                  Yes  ...
# 5938          Yes               Yes     Fiber optic                   No  ...
# 4488          Yes                No     Fiber optic                  Yes  ...
# 212           Yes                No              No  No internet service  ...
# 1742          Yes                No     Fiber optic                   No  ...
# 589           Yes               Yes             DSL                  Yes  ...
# 1608          Yes                No              No  No internet service  ...
# 2873          Yes               Yes     Fiber optic                   No  ...
# 1083          Yes                No     Fiber optic                   No  ...
# 5794          Yes               Yes     Fiber optic                   No  ...
# 2889           No  No phone service             DSL                  Yes  ...
# 1452           No  No phone service             DSL                  Yes  ...
# 5949           No  No phone service             DSL                   No  ...
# 2381          Yes                No              No  No internet service  ...
# 1515          Yes               Yes             DSL                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 1110                  Yes                   No                   No
# 5938                  Yes                  Yes                  Yes
# 4488                   No                   No                   No
# 212   No internet service  No internet service  No internet service
# 1742                   No                   No                  Yes
# 589                   Yes                  Yes                  Yes
# 1608  No internet service  No internet service  No internet service
# 2873                   No                   No                  Yes
# 1083                   No                   No                   No
# 5794                  Yes                  Yes                  Yes
# 2889                  Yes                   No                  Yes
# 1452                   No                   No                  Yes
# 5949                   No                  Yes                   No
# 2381  No internet service  No internet service  No internet service
# 1515                  Yes                  Yes                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 1110                   No        Two year               No
# 5938                  Yes  Month-to-month              Yes
# 4488                   No  Month-to-month              Yes
# 212   No internet service        Two year               No
# 1742                   No  Month-to-month              Yes
# 589                   Yes        Two year               No
# 1608  No internet service        One year              Yes
# 2873                  Yes  Month-to-month              Yes
# 1083                  Yes  Month-to-month              Yes
# 5794                  Yes        Two year              Yes
# 2889                   No        One year               No
# 1452                  Yes  Month-to-month              Yes
# 5949                  Yes  Month-to-month               No
# 2381  No internet service        One year               No
# 1515                  Yes        One year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 1110  Bank transfer (automatic)          39.60       2424.50     No
# 5938           Electronic check         108.90       3625.20     No
# 4488    Credit card (automatic)          74.15       3229.40    Yes
# 212                Mailed check          19.75       1124.20     No
# 1742  Bank transfer (automatic)          87.15        183.75    Yes
# 589            Electronic check          90.40       6668.05     No
# 1608               Mailed check          20.10        279.50     No
# 2873  Bank transfer (automatic)          94.70       2362.10    Yes
# 1083           Electronic check          80.95        171.15    Yes
# 5794  Bank transfer (automatic)         109.75       7932.50     No
# 2889               Mailed check          50.00       2919.85     No
# 1452    Credit card (automatic)          48.80       2555.05     No
# 5949           Electronic check          44.95       3085.35     No
# 2381               Mailed check          19.50        226.80     No
# 1515           Electronic check          68.60       2877.05     No
#
# [15 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
df[['tenure', 'MonthlyCharges', 'TotalCharges']].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7032.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2266.771362
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.850000   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
df['tenure'].loc[df['Churn']=='Yes'].hist(bins = 5);

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df.groupby(['Churn', 'gender'])['gender'].count() #sometimes sum() is count()!!!
# Out:
# Churn  gender
# No     Female    2549
#        Male      2625
# Yes    Female     939
#        Male       930
# Name: gender, dtype: int64

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 909   0835-JKADZ  Female              0      No         No      71
# 52    6575-SUVOI  Female              1     Yes         No      25
# 2451  3325-FUYCG    Male              0     Yes        Yes      28
# 6259  2661-GKBTK    Male              0     Yes        Yes      60
# 4063  3045-XETSH  Female              0      No         No      10
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 909           Yes           Yes     Fiber optic             No  ...
# 52            Yes           Yes             DSL            Yes  ...
# 2451          Yes           Yes     Fiber optic            Yes  ...
# 6259          Yes            No             DSL             No  ...
# 4063          Yes           Yes     Fiber optic             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 909               Yes         Yes         Yes             Yes        Two year
# 52                 No         Yes         Yes              No  Month-to-month
# 2451               No          No         Yes             Yes        One year
# 6259               No         Yes         Yes             Yes        Two year
# 4063              Yes          No          No             Yes  Month-to-month
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 909               Yes           Electronic check         111.25       7984.15
# 52                Yes    Credit card (automatic)          69.50       1752.65
# 2451               No           Electronic check         106.10       2847.40
# 6259               No  Bank transfer (automatic)          76.95       4543.95
# 4063              Yes           Electronic check          94.85        953.45
#
#       Churn
# 909      No
# 52       No
# 2451    Yes
# 6259     No
# 4063    Yes
#
# [5 rows x 21 columns]

# %%
def gender_enc(string):
    if string == 'Female':
        return 0
    else:
        return 1

gender_enc('Male')
# Out:
# 1

# %%
df['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
df['gender'] = df['gender'].apply(lambda row: gender_enc(row)) #axis = 1 means down column(s), axis = 0 means across row(s)
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1314  9831-BPFRI       0              0     Yes        Yes      39
# 5515  2892-GESUL       0              0     Yes        Yes      18
# 7041  8361-LTMKD       1              1     Yes         No       4
# 2397  3722-WPXTK       1              0      No         No       1
# 5371  0877-SDMBN       0              0      No         No      54
# 62    0526-SXDJP       1              0     Yes         No      72
# 1883  8840-DQLGN       0              1     Yes         No      35
# 5290  0774-RMNUW       0              0     Yes        Yes      71
# 6727  0749-IRGQE       0              1     Yes         No      13
# 2559  8263-QMNTJ       1              0     Yes         No      72
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1314          Yes               Yes     Fiber optic                   No  ...
# 5515          Yes                No              No  No internet service  ...
# 7041          Yes               Yes     Fiber optic                   No  ...
# 2397          Yes                No     Fiber optic                   No  ...
# 5371          Yes               Yes     Fiber optic                  Yes  ...
# 62             No  No phone service             DSL                  Yes  ...
# 1883          Yes               Yes     Fiber optic                  Yes  ...
# 5290           No  No phone service             DSL                  Yes  ...
# 6727           No  No phone service             DSL                   No  ...
# 2559          Yes               Yes     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 1314                  Yes                  Yes                   No
# 5515  No internet service  No internet service  No internet service
# 7041                   No                   No                   No
# 2397                   No                   No                  Yes
# 5371                  Yes                   No                  Yes
# 62                    Yes                   No                   No
# 1883                   No                  Yes                  Yes
# 5290                   No                  Yes                  Yes
# 6727                   No                   No                  Yes
# 2559                  Yes                  Yes                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 1314                   No        One year              Yes
# 5515  No internet service        Two year               No
# 7041                   No  Month-to-month              Yes
# 2397                  Yes  Month-to-month              Yes
# 5371                  Yes        One year              Yes
# 62                     No        Two year               No
# 1883                   No  Month-to-month              Yes
# 5290                  Yes        Two year               No
# 6727                  Yes  Month-to-month               No
# 2559                  Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 1314           Electronic check          89.55       3474.45    Yes
# 5515               Mailed check          19.35        309.25     No
# 7041               Mailed check          74.40        306.60    Yes
# 2397           Electronic check          88.35         88.35    Yes
# 5371  Bank transfer (automatic)         103.95       5639.05    Yes
# 62    Bank transfer (automatic)          42.10       2962.00     No
# 1883  Bank transfer (automatic)         100.50       3653.35    Yes
# 5290  Bank transfer (automatic)          59.70       4122.65     No
# 6727           Electronic check          45.30        528.45     No
# 2559           Electronic check         115.55       8425.30     No
#
# [10 rows x 21 columns]

# %%
df['gender'].value_counts()
# Out:
# 1    3555
# 0    3488
# Name: gender, dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.describe().columns
# Out:
# Index(['gender', 'SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
cat_cols = ['Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod']
cat_cols
# Out:
# ['Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
df['Partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
for col in cat_cols:
    print(df[col].value_counts())
    print()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
#
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64
#
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64
#
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64
#
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64
#
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64
#
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64
#
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64
#
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64
#
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: StreamingTV, dtype: int64
#
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64
#
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64
#
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64
#
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
def yes_no(string):
    if string == 'Yes':
        return 1
    else:
        return 0

# %%
def service(string):
    if string == 'Yes':
        return 1
    elif string == 'No':
        return 0 
    else:
        return -1 # no internet/phone service

# %%
def internet_service(string):
    if string == 'Fiber optic':
        return 2
    elif string == 'DSL':
        return 1
    else:
        return 0

# %%
def contract(string):
    if string == 'Month-to-month':
        return 1
    elif string == 'One year':
        return 2
    else:
        return 3

# %%
def pay_meth(string):
    if string == 'Electronic check':
        return 1
    elif string == 'Mailed check':
        return 2
    elif string == 'Bank transfer (automatic)':
        return 3
    else:
        return 4

# %%
import numpy as np

# %%
f = lambda x: x + 5
f(2)
# Out:
# 7

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
# change columns with yes or no categories
yes_no_ = ['Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']
for col in yes_no_:
    df[col] = df[col].apply(lambda row: yes_no(row))

# change columns with internet service categories
internet_service_ = ['InternetService']
for col in internet_service_:
    df[col] =  df[col].apply(lambda row: internet_service(row))

# change columns with yes, no, or no internet or phone categories
service_ = ['MultipleLines'
            , 'OnlineSecurity'
            , 'OnlineBackup'
            , 'DeviceProtection'
            , 'TechSupport'
            , 'StreamingTV'
            , 'StreamingMovies']
for col in service_:
    df[col] = df[col].apply(lambda row: service(row))

# change columns with contract categories
contract_ = ['Contract']
for col in contract_:
    df[col] = df[col].apply(lambda row: contract(row))

# change columns with payment categories
pay_meth_ = ['PaymentMethod']
for col in pay_meth_:
    df[col] = df[col].apply(lambda row: pay_meth(row))
    
df.sample(15)
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 4619  4290-BSXUX       1              0        1           0       3
# 6415  8224-UAXBZ       0              0        1           0      58
# 5024  8774-GSBUN       1              0        1           0      72
# 4489  8259-DZLIZ       0              0        1           1      64
# 1592  8387-MOJJT       0              0        1           1      42
# 1860  3279-DYZQM       1              0        1           1      71
# 1675  6311-UEUME       0              0        0           0      29
# 4202  3146-JTQHR       1              0        1           0      10
# 4616  4338-EYCER       1              0        1           0      21
# 4266  5445-PZWGX       1              0        0           0      62
# 1299  4566-QVRRW       0              0        1           0      11
# 3879  7359-PTSXY       1              0        0           0       1
# 2297  3870-MQAMG       0              0        1           0      54
# 1593  0620-XEFWH       1              0        1           1       4
# 3977  4778-IZARL       1              0        1           0      63
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 4619             1              1                2               0  ...
# 6415             0             -1                1               1  ...
# 5024             1              1                0              -1  ...
# 4489             1              1                1               0  ...
# 1592             1              0                2               0  ...
# 1860             1              0                0              -1  ...
# 1675             1              0                2               0  ...
# 4202             1              0                0              -1  ...
# 4616             1              0                1               0  ...
# 4266             1              1                2               1  ...
# 1299             1              0                1               0  ...
# 3879             1              0                1               0  ...
# 2297             1              1                2               0  ...
# 1593             1              0                0              -1  ...
# 3977             1              0                2               1  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 4619                 0            1            0                0         1
# 6415                 0            0            1                0         2
# 5024                -1           -1           -1               -1         3
# 4489                 0            0            0                0         2
# 1592                 0            0            1                0         1
# 1860                -1           -1           -1               -1         3
# 1675                 0            0            1                0         1
# 4202                -1           -1           -1               -1         2
# 4616                 0            0            1                0         1
# 4266                 0            1            0                1         2
# 1299                 0            0            0                0         1
# 3879                 0            0            0                0         1
# 2297                 1            1            1                1         2
# 1593                -1           -1           -1               -1         1
# 3977                 1            1            1                1         3
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 4619                 1              3           79.65        251.75    Yes
# 6415                 1              1           45.35       2540.10     No
# 5024                 0              2           25.40       1797.10     No
# 4489                 1              3           53.85       3399.85     No
# 1592                 1              4           77.95       3384.00    Yes
# 1860                 0              2           19.45       1378.45     No
# 1675                 1              1           78.90       2384.15    Yes
# 4202                 0              3           19.60        189.45     No
# 4616                 0              3           54.60       1125.20     No
# 4266                 0              1          102.00       6529.25    Yes
# 1299                 1              1           44.05        483.70    Yes
# 3879                 0              1           45.75         45.75    Yes
# 2297                 0              1          110.35       5893.15    Yes
# 1593                 0              2           18.85         84.20     No
# 3977                 1              4          110.10       6705.70     No
#
# [15 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
#  16  PaperlessBilling  7043 non-null   int64
#  17  PaymentMethod     7043 non-null   int64
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(17), object(2)
# memory usage: 1.1+ MB

# %%
df['TotalCharges'].loc[df['TotalCharges'].isnull()] # np.null is from numpy
# Out:
# 488    NaN
# 753    NaN
# 936    NaN
# 1082   NaN
# 1340   NaN
# 3331   NaN
# 3826   NaN
# 4380   NaN
# 5218   NaN
# 6670   NaN
# 6754   NaN
# Name: TotalCharges, dtype: float64

# %%
# df.dropna(axis=0, inplace=True) # delete the rows 
df.fillna(df['TotalCharges'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
#  16  PaperlessBilling  7043 non-null   int64
#  17  PaymentMethod     7043 non-null   int64
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(17), object(2)
# memory usage: 1.1+ MB

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['Churn'] = df['Churn'].apply(lambda row: yes_no(row))
df['Churn'].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
#  16  PaperlessBilling  7043 non-null   int64
#  17  PaymentMethod     7043 non-null   int64
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   float64
#  20  Churn             7043 non-null   int64
# dtypes: float64(2), int64(18), object(1)
# memory usage: 1.1+ MB

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# %%
rfc = RandomForestClassifier(random_state=42
                             , n_jobs=-1
                            )
rfr = RandomForestRegressor(random_state=42
                            , n_jobs=-1
                           )

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 4569  7639-SUPCW       0              0        0           0      22
# 5659  0674-GCDXG       1              0        0           0      63
# 3699  1137-DGOWI       0              0        1           0      30
# 1704  0107-YHINA       1              0        0           1       1
# 2171  3995-WFCSM       0              0        0           0       2
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 4569             1              0                1               1  ...
# 5659             1              1                1               1  ...
# 3699             1              0                1               0  ...
# 1704             1              1                2               0  ...
# 2171             1              0                1               0  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 4569                 0            0            0                0         1
# 5659                 1            1            0                1         3
# 3699                 1            1            0                1         2
# 1704                 1            0            1                1         1
# 2171                 1            0            0                1         1
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 4569                 1              4           48.80       1054.60      1
# 5659                 1              3           71.90       4479.20      0
# 3699                 0              3           70.25       2198.90      0
# 1704                 1              1           99.75         99.75      1
# 2171                 0              1           60.85        111.40      0
#
# [5 rows x 21 columns]

# %%
int(df.shape[0] * 0.85)
# Out:
# 5986

# %%
split = int(df.shape[0] * 0.85)

df.drop(columns=['customerID'], inplace=True)
df.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 1583       0              0        1           1       6             1
# 3482       1              0        0           0      19             1
# 1487       0              0        0           0      56             1
# 5887       1              0        0           1      17             1
# 5027       1              1        1           0      10             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 1583              1                1               0             0
# 3482              0                1               0             0
# 1487              1                2               0             1
# 5887              0                1               1             0
# 5027              1                2               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 1583                 0            0            0                0         1
# 3482                 0            0            0                0         1
# 1487                 1            0            1                1         2
# 5887                 0            0            0                0         1
# 5027                 0            0            0                1         1
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 1583                 1              4           48.95        273.25      0
# 3482                 1              3           45.00        865.85      0
# 1487                 1              1          106.80       5914.40      0
# 5887                 1              2           50.30        846.80      0
# 5027                 0              1           85.55        851.75      1

# %%
df_train = df[:split].copy()
df_test = df[split:].copy()

# %%
X_train = df_train.drop(columns=['Churn']).copy()
y_train = df_train['Churn'].copy()

X_test = df_test.drop(columns=['Churn']).copy()
y_test = df_test['Churn'].copy()

# %%
rfc.fit(X_train, y_train) # fit the training set with the RandomForestClassifier object rfc
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
df.iloc[-1]
# Out:
# gender                 1.00
# SeniorCitizen          0.00
# Partner                0.00
# Dependents             0.00
# tenure                66.00
# PhoneService           1.00
# MultipleLines          0.00
# InternetService        2.00
# OnlineSecurity         1.00
# OnlineBackup           0.00
# DeviceProtection       1.00
# TechSupport            1.00
# StreamingTV            1.00
# StreamingMovies        1.00
# Contract               3.00
# PaperlessBilling       1.00
# PaymentMethod          3.00
# MonthlyCharges       105.65
# TotalCharges        6844.50
# Churn                  0.00
# Name: 7042, dtype: float64

# %%
df.tail(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 7040             -1                1               1             0
# 7041              1                2               0             0
# 7042              0                2               1             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 7040                 0            0            0                0         1
# 7041                 0            0            0                0         1
# 7042                 1            1            1                1         3
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 7040                 1              1           29.60        346.45      0
# 7041                 1              2           74.40        306.60      1
# 7042                 1              3          105.65       6844.50      0

# %%
X_test.iloc[-1].values
# Out:
# array([1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 6.6000e+01,
#        1.0000e+00, 0.0000e+00, 2.0000e+00, 1.0000e+00, 0.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 3.0000e+00,
#        1.0000e+00, 3.0000e+00, 1.0565e+02, 6.8445e+03])

# %%
X_test.iloc[-1].values.reshape(1,-1)
# Out:
# array([[1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 6.6000e+01,
#         1.0000e+00, 0.0000e+00, 2.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 3.0000e+00,
#         1.0000e+00, 3.0000e+00, 1.0565e+02, 6.8445e+03]])

# %%
rfc.predict(X_test.iloc[-1].values.reshape(1,-1))
# Out:
# array([0])

# %%
rfc.predict(X_test.iloc[-2].values.reshape(1,-1))
# Out:
# array([1])

# %%
rfc.predict(X_test.iloc[-3].values.reshape(1,-1))
# Out:
# array([0])

# %%
rfc.predict(X_test)
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
y_test
# Out:
# 5986    0
# 5987    0
# 5988    0
# 5989    1
# 5990    0
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 1057, dtype: int64

# %%
correct=0
incorrect=0

for i in range(len(y_test)):
    if rfc.predict(X_test.iloc[i].values.reshape(1,-1)) == y_test.iloc[i]:
        correct += 1
    else:
        incorrect += 1

# %%
correct
# Out:
# 841

# %%
incorrect
# Out:
# 216

# %%
correct / (correct + incorrect)
# Out:
# 0.7956480605487228

# %%
rfc.feature_importances_
# Out:
# array([0.02715609, 0.02103392, 0.02215622, 0.01937451, 0.16371163,
#        0.00408219, 0.02260997, 0.04390206, 0.0243149 , 0.02746238,
#        0.0235934 , 0.02491997, 0.02149133, 0.02103603, 0.07796486,
#        0.02574194, 0.06081018, 0.17648219, 0.19215622])

# %%
X_train.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges'],
#       dtype='object')

# %%
# Regression Model

# %%
df.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 4248       0              0        1           0      56             1
# 5092       0              0        1           1       7             1
# 1148       0              0        0           0       2             1
# 1507       1              0        0           0      54             1
# 1373       1              0        0           1       1             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 4248              1                2               0             1
# 5092              0                0              -1            -1
# 1148              1                2               0             0
# 1507              0                0              -1            -1
# 1373              0                0              -1            -1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 4248                 1            1            0                0         1
# 5092                -1           -1           -1               -1         1
# 1148                 0            0            1                1         1
# 1507                -1           -1           -1               -1         3
# 1373                -1           -1           -1               -1         1
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 4248                 0              1           90.55       5116.60      0
# 5092                 0              2           20.45        150.75      0
# 1148                 1              1           95.15        196.90      1
# 1507                 0              4           19.65       1008.70      0
# 1373                 0              2           19.85         19.85      0

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
new_df = df[['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
       'TotalCharges']].copy()
new_df.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 4663       0              1        0           0       4             1
# 3315       1              1        1           0      66             1
# 4419       0              0        1           1       8             1
# 4869       1              0        0           0      16             1
# 6013       0              1        1           0      50             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 4663              1                2               0             0
# 3315              1                2               0             1
# 4419              0                0              -1            -1
# 4869              1                2               0             1
# 6013              1                2               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 4663                 0            0            0                0         1
# 3315                 1            1            1                1         2
# 4419                -1           -1           -1               -1         1
# 4869                 0            0            0                0         1
# 6013                 0            1            1                1         2
#
#       PaperlessBilling  PaymentMethod  TotalCharges
# 4663                 1              1        321.75
# 3315                 1              3       7051.95
# 4419                 0              4        139.75
# 4869                 1              2       1248.90
# 6013                 1              1       5189.75

# %%
new_df_train = new_df[:split].copy()
new_df_test = new_df[split:].copy()

# %%
new_df_train.shape
# Out:
# (5986, 18)

# %%
X_train = new_df_train.drop(columns=['TotalCharges']).copy()
y_train = new_df_train['TotalCharges'].copy()

X_test = new_df_test.drop(columns=['TotalCharges']).copy()
y_test = new_df_test['TotalCharges'].copy()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(random_state=42
                            , n_jobs = -1
                           )

# %%
rfr_model = rfr.fit(X_train, y_train)

# %%
rfr_model.predict(X_test.iloc[-1].values.reshape(1, -1))
# Out:
# array([7072.89325])

# %%
y_test.iloc[-1]
# Out:
# 6844.5

# %%
rfr_model.feature_importances_
# Out:
# array([2.77034405e-04, 1.94391444e-04, 2.43777355e-04, 2.30386801e-04,
#        6.94854436e-01, 4.97715496e-03, 7.72190003e-03, 9.44370859e-02,
#        3.86268571e-02, 3.50198659e-02, 2.25920039e-02, 3.44183955e-02,
#        2.93311807e-02, 3.58911245e-02, 4.28962214e-04, 2.44181437e-04,
#        5.11261311e-04])

# %%
from src import functions as f
# %load_ext autoreload
# %autoreload 2

# %%
f.add_two(1, 2, 3)
# Out:
# 18

# %%
f.return_df()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95       1889.50
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80       1990.50
# 7039              Yes    Credit card (automatic)         103.20       7362.90
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40        306.60
# 7042              Yes  Bank transfer (automatic)         105.65       6844.50
#
#       Churn
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
# ...     ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
#
# [7043 rows x 21 columns]
